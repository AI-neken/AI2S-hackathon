# %%
import pandas as pd
df_target = pd.read_csv('data/02_input_target.csv')
df_capacity = pd.read_csv('data/02_input_capacity.csv')
df_shipment_cost = pd.read_csv('data/02_03_input_shipmentsCost_example.csv')
df_production_cost = pd.read_csv('data/03_input_productionCost.csv')
df_shipment_cost
# Out:
#             Origin     Destination  Unit Cost
# 0            Japan       Australia      13.43
# 1            Japan          Brazil      10.42
# 2            Japan           Egypt       9.90
# 3            Japan           Italy      13.01
# 4            Japan    South Africa       8.92
# 5            Japan          France       5.60
# 6            Japan           India       6.75
# 7            Japan  United Kingdom      10.12
# 8            Japan          Russia      12.60
# 9        Australia          Brazil      10.07
# 10       Australia           Egypt       8.89
# 11       Australia           Italy       8.35
# 12       Australia    South Africa      13.61
# 13       Australia          France      10.61
# 14       Australia           India       7.78
# 15       Australia  United Kingdom       9.33
# 16       Australia          Russia      11.06
# 17          Brazil           Egypt      10.35
# 18          Brazil           Italy       8.28
# 19          Brazil    South Africa      10.39
# 20          Brazil          France       9.15
# 21          Brazil           India      10.28
# 22          Brazil  United Kingdom       7.30
# 23          Brazil          Russia      11.90
# 24           Egypt           Italy      10.86
# 25           Egypt    South Africa       9.72
# 26           Egypt          France      10.98
# 27           Egypt           India      11.43
# 28           Egypt  United Kingdom       8.90
# 29           Egypt          Russia       8.51
# 30           Italy    South Africa      12.76
# 31           Italy          France       8.42
# 32           Italy           India      10.82
# 33           Italy  United Kingdom       9.42
# 34           Italy          Russia       9.30
# 35    South Africa          France       9.98
# 36    South Africa           India       8.91
# 37    South Africa  United Kingdom       8.80
# 38    South Africa          Russia      10.81
# 39          France           India      12.11
# 40          France  United Kingdom       9.49
# 41          France          Russia       9.45
# 42           India  United Kingdom       6.87
# 43           India          Russia       8.97
# 44  United Kingdom          Russia      13.01

# %%
import pandas as pd
from ortools.linear_solver import pywraplp

# Carica i dataset necessari
demand_df = df_target       # Country, Product, Month, Quantity
capacity_df = df_capacity     # Country, Monthly Capacity
shipment_cost_df = df_shipment_cost # Origin, Destination, Product, Cost_per_Unit
production_cost_df = df_production_cost # Country, Product, Cost_per_Unit

# Prepara dizionari
demand_df['Key'] = list(zip(demand_df['Country'], demand_df['Product'], demand_df['Month']))
demand = dict(zip(demand_df['Key'], demand_df['Quantity']))

capacity = dict(zip(capacity_df['Country'], capacity_df['Monthly Capacity']))

# Creiamo un dizionario per i costi di trasporto
transport_costs = {}
for _, row in shipment_cost_df.iterrows():
    key = (row['Origin'], row['Destination'])
    transport_costs[key] = row['Unit Cost']
    # key_inf = (row['Destination'], row['Origin'])
    # transport_costs[key] = np.inf

# Creiamo un dizionario per i costi di produzione
production_costs = {}
for _, row in production_cost_df.iterrows():
    key = (row['Country'], row['Product'])
    production_costs[key] = row['Unit Cost']

# Impianti e mesi
plants = list(capacity.keys())
months = sorted(demand_df['Month'].unique())
demand_keys = list(demand.keys())

# Inizializza il solver OR-Tools
solver = pywraplp.Solver.CreateSolver('SAT')

# Variabili decisionali: quanto produce ogni impianto per soddisfare domanda (i,j,p,m)
x = {}
for i in plants:
    for (j, p, m) in demand_keys:
        x[i, j, p, m] = solver.NumVar(0, solver.infinity(), f'x_{i}_{j}_{p}_{m}')

# Variabile per il massimo carico (da minimizzare)
max_load = solver.NumVar(0, 1, 'max_load')

# 1. Vincolo di domanda
for (j, p, m) in demand_keys:
    solver.Add(solver.Sum(x[i, j, p, m] for i in plants) == demand[(j, p, m)])

# 2. Vincoli di capacità impianto
for i in plants:
    for m in months:
        monthly_prod = solver.Sum(x[i, j, p, m] for (j, p, m2) in demand_keys if m2 == m)
        solver.Add(monthly_prod <= capacity[i])

# 3. Vincoli per il carico massimo
for i in plants:
    for m in months:
        monthly_prod = solver.Sum(x[i, j, p, m] for (j, p, m2) in demand_keys if m2 == m)
        solver.Add(monthly_prod <= max_load * capacity[i])

# 4. Funzione obiettivo: Minimizzare i costi di produzione e trasporto
total_cost = solver.Sum(
    x[i, j, p, m] * transport_costs.get((i, j, p), 0) # Costo di trasporto
    for i in plants for (j, p, m) in demand_keys
)

# Aggiungi i costi di produzione alla funzione obiettivo
total_cost += solver.Sum(
    x[i, j, p, m] * production_costs.get((i, p), 0)  # Costo di produzione
    for i in plants for (j, p, m) in demand_keys
)

# Aggiungi l'obiettivo (costo totale da minimizzare)
solver.Minimize(total_cost*1e-7 + max_load)

# Risoluzione
status = solver.Solve()

# Output della soluzione
if status == pywraplp.Solver.OPTIMAL:
    print(f"Status: Ottimale")
    print(f"Carico massimo usato: {max_load.solution_value():.2%}")
    print("Costi totali:", solver.Objective().Value())
    
    # Crea due liste separate per il piano di produzione e quello di spedizione
    production_data = []
    shipment_data = []

if status == pywraplp.Solver.OPTIMAL:
    print(f'Status: Ottimale\nCarico massimo usato: {max_load.solution_value():.2%}')
    for (i, j, p, m), var in x.items():
        if var.solution_value() > 0:
            print(f'{i} produce {var.solution_value():.0f} unità per {j} ({p}) a {m}')
else:
    print('Nessuna soluzione ottimale trovata.')
# Out:
# Status: Ottimale
# Carico massimo usato: 100.00%
# Costi totali: 8.533171729000014
# Status: Ottimale
# Carico massimo usato: 100.00%
# Australia produce 1160 unità per Japan (BreatheEasy Inhalant) a Jan2004
# Australia produce 1187 unità per Japan (BreatheEasy Inhalant) a Feb2004
# Australia produce 1056 unità per Japan (BreatheEasy Inhalant) a Mar2004
# Australia produce 1134 unità per Japan (BreatheEasy Inhalant) a Apr2004
# Australia produce 1134 unità per Japan (BreatheEasy Inhalant) a May2004
# Australia produce 1166 unità per Japan (BreatheEasy Inhalant) a Jun2004
# Australia produce 1125 unità per Japan (BreatheEasy Inhalant) a Jul2004
# Australia produce 1268 unità per Japan (BreatheEasy Inhalant) a Aug2004
# Australia produce 1251 unità per Japan (BreatheEasy Inhalant) a Sep2004
# Australia produce 1015 unità per Japan (BreatheEasy Inhalant) a Oct2004
# Australia produce 1177 unità per Japan (BreatheEasy Inhalant) a Nov2004
# Australia produce 1189 unità per Japan (BreatheEasy Inhalant) a Dec2004
# Australia produce 683 unità per Japan (SmilesSoPure Waterpik) a Jan2004
# Australia produce 664 unità per Japan (SmilesSoPure Waterpik) a Feb2004
# Australia produce 653 unità per Japan (SmilesSoPure Waterpik) a Mar2004
# Australia produce 631 unità per Japan (SmilesSoPure Waterpik) a Apr2004
# Australia produce 725 unità per Japan (SmilesSoPure Waterpik) a May2004
# Australia produce 606 unità per Japan (SmilesSoPure Waterpik) a Jun2004
# Australia produce 715 unità per Japan (SmilesSoPure Waterpik) a Jul2004
# Australia produce 673 unità per Japan (SmilesSoPure Waterpik) a Aug2004
# Australia produce 698 unità per Japan (SmilesSoPure Waterpik) a Sep2004
# Australia produce 676 unità per Japan (SmilesSoPure Waterpik) a Oct2004
# Australia produce 669 unità per Japan (SmilesSoPure Waterpik) a Nov2004
# Australia produce 654 unità per Japan (SmilesSoPure Waterpik) a Dec2004
# Australia produce 1893 unità per Japan (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1903 unità per Japan (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1760 unità per Japan (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1733 unità per Japan (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1957 unità per Japan (SparklingGlow Toothpaste) a May2004
# Australia produce 1837 unità per Japan (SparklingGlow Toothpaste) a Jun2004
# Australia produce 2021 unità per Japan (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1832 unità per Japan (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1894 unità per Japan (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1843 unità per Japan (SparklingGlow Toothpaste) a Oct2004
# Australia produce 2029 unità per Japan (SparklingGlow Toothpaste) a Nov2004
# Australia produce 1925 unità per Japan (SparklingGlow Toothpaste) a Dec2004
# Australia produce 1398 unità per Japan (CleanSkin Acne Treatment) a Jan2004
# Australia produce 1291 unità per Japan (CleanSkin Acne Treatment) a Feb2004
# Australia produce 1379 unità per Japan (CleanSkin Acne Treatment) a Mar2004
# Australia produce 1295 unità per Japan (CleanSkin Acne Treatment) a Apr2004
# Australia produce 607 unità per Japan (CleanSkin Acne Treatment) a May2004
# Australia produce 1375 unità per Japan (CleanSkin Acne Treatment) a Jun2004
# Australia produce 1232 unità per Japan (CleanSkin Acne Treatment) a Jul2004
# Australia produce 1300 unità per Japan (CleanSkin Acne Treatment) a Aug2004
# Australia produce 1279 unità per Japan (CleanSkin Acne Treatment) a Sep2004
# Australia produce 303 unità per Japan (CleanSkin Acne Treatment) a Oct2004
# Australia produce 233 unità per Japan (CleanSkin Acne Treatment) a Nov2004
# Australia produce 811 unità per Japan (CleanSkin Acne Treatment) a Dec2004
# Australia produce 1326 unità per Japan (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce 1299 unità per Japan (SoothingSerenity Hand Sanitizer) a Feb2004
# Australia produce 1332 unità per Japan (SoothingSerenity Hand Sanitizer) a Mar2004
# Australia produce 1376 unità per Japan (SoothingSerenity Hand Sanitizer) a Apr2004
# Australia produce 1313 unità per Japan (SoothingSerenity Hand Sanitizer) a May2004
# Australia produce 1283 unità per Japan (SoothingSerenity Hand Sanitizer) a Jun2004
# Australia produce 1296 unità per Japan (SoothingSerenity Hand Sanitizer) a Jul2004
# Australia produce 1256 unità per Japan (SoothingSerenity Hand Sanitizer) a Aug2004
# Australia produce 1200 unità per Japan (SoothingSerenity Hand Sanitizer) a Sep2004
# Australia produce 1434 unità per Japan (SoothingSerenity Hand Sanitizer) a Oct2004
# Australia produce 1242 unità per Japan (SoothingSerenity Hand Sanitizer) a Nov2004
# Australia produce 1335 unità per Japan (SoothingSerenity Hand Sanitizer) a Dec2004
# Australia produce 602 unità per Japan (SilkySkin Moisturizing Cream) a Jan2004
# Australia produce 643 unità per Japan (SilkySkin Moisturizing Cream) a Feb2004
# Australia produce 554 unità per Japan (SilkySkin Moisturizing Cream) a Mar2004
# Australia produce 497 unità per Japan (SilkySkin Moisturizing Cream) a Apr2004
# Australia produce 546 unità per Japan (SilkySkin Moisturizing Cream) a May2004
# Australia produce 551 unità per Japan (SilkySkin Moisturizing Cream) a Jun2004
# Australia produce 611 unità per Japan (SilkySkin Moisturizing Cream) a Jul2004
# Australia produce 587 unità per Japan (SilkySkin Moisturizing Cream) a Aug2004
# Australia produce 522 unità per Japan (SilkySkin Moisturizing Cream) a Sep2004
# Australia produce 547 unità per Japan (SilkySkin Moisturizing Cream) a Oct2004
# Australia produce 530 unità per Japan (SilkySkin Moisturizing Cream) a Nov2004
# Australia produce 567 unità per Japan (SilkySkin Moisturizing Cream) a Dec2004
# Australia produce 1101 unità per Japan (RadiantRose Baby Massage Oil) a Jan2004
# Australia produce 1096 unità per Japan (RadiantRose Baby Massage Oil) a Feb2004
# Australia produce 1102 unità per Japan (RadiantRose Baby Massage Oil) a Mar2004
# Australia produce 1142 unità per Japan (RadiantRose Baby Massage Oil) a Apr2004
# Australia produce 972 unità per Japan (RadiantRose Baby Massage Oil) a May2004
# Australia produce 964 unità per Japan (RadiantRose Baby Massage Oil) a Jun2004
# Australia produce 983 unità per Japan (RadiantRose Baby Massage Oil) a Jul2004
# Australia produce 998 unità per Japan (RadiantRose Baby Massage Oil) a Aug2004
# Australia produce 1122 unità per Japan (RadiantRose Baby Massage Oil) a Sep2004
# Australia produce 1076 unità per Japan (RadiantRose Baby Massage Oil) a Oct2004
# Australia produce 982 unità per Japan (RadiantRose Baby Massage Oil) a Nov2004
# Australia produce 1090 unità per Japan (RadiantRose Baby Massage Oil) a Dec2004
# Australia produce 1128 unità per Japan (PurePore Insect Repellent Spray) a Jan2004
# Australia produce 1103 unità per Japan (PurePore Insect Repellent Spray) a Feb2004
# Australia produce 1139 unità per Japan (PurePore Insect Repellent Spray) a Mar2004
# Australia produce 1045 unità per Japan (PurePore Insect Repellent Spray) a Apr2004
# Australia produce 1127 unità per Japan (PurePore Insect Repellent Spray) a May2004
# Australia produce 1089 unità per Japan (PurePore Insect Repellent Spray) a Jun2004
# Australia produce 1035 unità per Japan (PurePore Insect Repellent Spray) a Jul2004
# Australia produce 1139 unità per Japan (PurePore Insect Repellent Spray) a Aug2004
# Australia produce 1081 unità per Japan (PurePore Insect Repellent Spray) a Sep2004
# Australia produce 1177 unità per Japan (PurePore Insect Repellent Spray) a Oct2004
# Australia produce 1116 unità per Japan (PurePore Insect Repellent Spray) a Nov2004
# Australia produce 1163 unità per Japan (PurePore Insect Repellent Spray) a Dec2004
# Australia produce 1867 unità per Australia (BreatheEasy Inhalant) a Jan2004
# Australia produce 1675 unità per Australia (BreatheEasy Inhalant) a Feb2004
# Australia produce 1721 unità per Australia (BreatheEasy Inhalant) a Mar2004
# Australia produce 1957 unità per Australia (BreatheEasy Inhalant) a Apr2004
# Australia produce 1904 unità per Australia (BreatheEasy Inhalant) a May2004
# Australia produce 1928 unità per Australia (BreatheEasy Inhalant) a Jun2004
# Australia produce 1789 unità per Australia (BreatheEasy Inhalant) a Jul2004
# Australia produce 1827 unità per Australia (BreatheEasy Inhalant) a Aug2004
# Australia produce 1929 unità per Australia (BreatheEasy Inhalant) a Sep2004
# Australia produce 1652 unità per Australia (BreatheEasy Inhalant) a Oct2004
# Australia produce 2034 unità per Australia (BreatheEasy Inhalant) a Nov2004
# Australia produce 1699 unità per Australia (BreatheEasy Inhalant) a Dec2004
# Australia produce 1324 unità per Australia (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1242 unità per Australia (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1324 unità per Australia (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1381 unità per Australia (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1202 unità per Australia (SparklingGlow Toothpaste) a May2004
# Australia produce 1385 unità per Australia (SparklingGlow Toothpaste) a Jun2004
# Australia produce 1272 unità per Australia (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1311 unità per Australia (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1321 unità per Australia (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1262 unità per Australia (SparklingGlow Toothpaste) a Oct2004
# Australia produce 1256 unità per Australia (SparklingGlow Toothpaste) a Nov2004
# Australia produce 1231 unità per Australia (SparklingGlow Toothpaste) a Dec2004
# Australia produce 299 unità per Australia (LittleLullaby Diaper Cream) a Jan2004
# Australia produce 65 unità per Australia (LittleLullaby Diaper Cream) a Jun2004
# Australia produce 1042 unità per Australia (RadiantRose Baby Massage Oil) a Jan2004
# Australia produce 1068 unità per Australia (RadiantRose Baby Massage Oil) a Feb2004
# Australia produce 1113 unità per Australia (RadiantRose Baby Massage Oil) a Mar2004
# Australia produce 1074 unità per Australia (RadiantRose Baby Massage Oil) a Apr2004
# Australia produce 1051 unità per Australia (RadiantRose Baby Massage Oil) a May2004
# Australia produce 1070 unità per Australia (RadiantRose Baby Massage Oil) a Jun2004
# Australia produce 1048 unità per Australia (RadiantRose Baby Massage Oil) a Jul2004
# Australia produce 1113 unità per Australia (RadiantRose Baby Massage Oil) a Aug2004
# Australia produce 1141 unità per Australia (RadiantRose Baby Massage Oil) a Sep2004
# Australia produce 1121 unità per Australia (RadiantRose Baby Massage Oil) a Oct2004
# Australia produce 1137 unità per Australia (RadiantRose Baby Massage Oil) a Nov2004
# Australia produce 1123 unità per Australia (RadiantRose Baby Massage Oil) a Dec2004
# Australia produce 770 unità per Brazil (BreatheEasy Inhalant) a Jan2004
# Australia produce 757 unità per Brazil (BreatheEasy Inhalant) a Feb2004
# Australia produce 737 unità per Brazil (BreatheEasy Inhalant) a Mar2004
# Australia produce 743 unità per Brazil (BreatheEasy Inhalant) a Apr2004
# Australia produce 872 unità per Brazil (BreatheEasy Inhalant) a May2004
# Australia produce 766 unità per Brazil (BreatheEasy Inhalant) a Jun2004
# Australia produce 756 unità per Brazil (BreatheEasy Inhalant) a Jul2004
# Australia produce 741 unità per Brazil (BreatheEasy Inhalant) a Aug2004
# Australia produce 733 unità per Brazil (BreatheEasy Inhalant) a Sep2004
# Australia produce 845 unità per Brazil (BreatheEasy Inhalant) a Oct2004
# Australia produce 805 unità per Brazil (BreatheEasy Inhalant) a Nov2004
# Australia produce 794 unità per Brazil (BreatheEasy Inhalant) a Dec2004
# Australia produce 2066 unità per Brazil (SmilesSoPure Waterpik) a Jan2004
# Australia produce 1919 unità per Brazil (SmilesSoPure Waterpik) a Feb2004
# Australia produce 2049 unità per Brazil (SmilesSoPure Waterpik) a Mar2004
# Australia produce 2036 unità per Brazil (SmilesSoPure Waterpik) a Apr2004
# Australia produce 1959 unità per Brazil (SmilesSoPure Waterpik) a May2004
# Australia produce 1908 unità per Brazil (SmilesSoPure Waterpik) a Jun2004
# Australia produce 2017 unità per Brazil (SmilesSoPure Waterpik) a Jul2004
# Australia produce 2067 unità per Brazil (SmilesSoPure Waterpik) a Aug2004
# Australia produce 1950 unità per Brazil (SmilesSoPure Waterpik) a Sep2004
# Australia produce 2219 unità per Brazil (SmilesSoPure Waterpik) a Oct2004
# Australia produce 1827 unità per Brazil (SmilesSoPure Waterpik) a Nov2004
# Australia produce 1904 unità per Brazil (SmilesSoPure Waterpik) a Dec2004
# Australia produce 1544 unità per Brazil (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1501 unità per Brazil (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1380 unità per Brazil (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1464 unità per Brazil (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1540 unità per Brazil (SparklingGlow Toothpaste) a May2004
# Australia produce 1290 unità per Brazil (SparklingGlow Toothpaste) a Jun2004
# Australia produce 1381 unità per Brazil (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1402 unità per Brazil (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1440 unità per Brazil (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1380 unità per Brazil (SparklingGlow Toothpaste) a Oct2004
# Australia produce 1450 unità per Brazil (SparklingGlow Toothpaste) a Nov2004
# Australia produce 1494 unità per Brazil (SparklingGlow Toothpaste) a Dec2004
# Australia produce 951 unità per Brazil (LittleLullaby Diaper Cream) a Jan2004
# Australia produce 928 unità per Brazil (LittleLullaby Diaper Cream) a Mar2004
# Australia produce 929 unità per Brazil (LittleLullaby Diaper Cream) a Apr2004
# Australia produce 436 unità per Brazil (LittleLullaby Diaper Cream) a May2004
# Australia produce 903 unità per Brazil (LittleLullaby Diaper Cream) a Jun2004
# Australia produce 965 unità per Brazil (LittleLullaby Diaper Cream) a Jul2004
# Australia produce 871 unità per Brazil (LittleLullaby Diaper Cream) a Sep2004
# Australia produce 480 unità per Brazil (LittleLullaby Diaper Cream) a Oct2004
# Australia produce 488 unità per Brazil (LittleLullaby Diaper Cream) a Nov2004
# Australia produce 811 unità per Brazil (LittleLullaby Diaper Cream) a Dec2004
# Australia produce 1726 unità per Brazil (PurePore Insect Repellent Spray) a Jan2004
# Australia produce 1812 unità per Brazil (PurePore Insect Repellent Spray) a Feb2004
# Australia produce 1601 unità per Italy (LittleLullaby Diaper Cream) a Apr2004
# Australia produce 1684 unità per Italy (LittleLullaby Diaper Cream) a May2004
# Australia produce 1771 unità per Italy (LittleLullaby Diaper Cream) a Jun2004
# Australia produce 1607 unità per Italy (LittleLullaby Diaper Cream) a Jul2004
# Australia produce 1628 unità per Italy (LittleLullaby Diaper Cream) a Aug2004
# Australia produce 1621 unità per Italy (LittleLullaby Diaper Cream) a Sep2004
# Australia produce 1506 unità per Italy (LittleLullaby Diaper Cream) a Oct2004
# Australia produce 1678 unità per Italy (LittleLullaby Diaper Cream) a Nov2004
# Australia produce 1742 unità per Italy (LittleLullaby Diaper Cream) a Dec2004
# Australia produce 1795 unità per South Africa (BreatheEasy Inhalant) a Jan2004
# Australia produce 1762 unità per South Africa (BreatheEasy Inhalant) a Feb2004
# Australia produce 1848 unità per South Africa (BreatheEasy Inhalant) a Mar2004
# Australia produce 1963 unità per South Africa (BreatheEasy Inhalant) a Apr2004
# Australia produce 1885 unità per South Africa (BreatheEasy Inhalant) a May2004
# Australia produce 1965 unità per South Africa (BreatheEasy Inhalant) a Jun2004
# Australia produce 1982 unità per South Africa (BreatheEasy Inhalant) a Jul2004
# Australia produce 1819 unità per South Africa (BreatheEasy Inhalant) a Aug2004
# Australia produce 1935 unità per South Africa (BreatheEasy Inhalant) a Sep2004
# Australia produce 1667 unità per South Africa (BreatheEasy Inhalant) a Oct2004
# Australia produce 1730 unità per South Africa (BreatheEasy Inhalant) a Nov2004
# Australia produce 2074 unità per South Africa (BreatheEasy Inhalant) a Dec2004
# Australia produce 205 unità per France (SmilesSoPure Waterpik) a Jan2004
# Australia produce 176 unità per France (SmilesSoPure Waterpik) a Feb2004
# Australia produce 231 unità per France (SmilesSoPure Waterpik) a Mar2004
# Australia produce 201 unità per France (SmilesSoPure Waterpik) a Apr2004
# Australia produce 191 unità per France (SmilesSoPure Waterpik) a May2004
# Australia produce 185 unità per France (SmilesSoPure Waterpik) a Jun2004
# Australia produce 220 unità per France (SmilesSoPure Waterpik) a Jul2004
# Australia produce 181 unità per France (SmilesSoPure Waterpik) a Aug2004
# Australia produce 232 unità per France (SmilesSoPure Waterpik) a Sep2004
# Australia produce 226 unità per France (SmilesSoPure Waterpik) a Oct2004
# Australia produce 213 unità per France (SmilesSoPure Waterpik) a Nov2004
# Australia produce 185 unità per France (SmilesSoPure Waterpik) a Dec2004
# Australia produce 1671 unità per France (CleanSkin Acne Treatment) a Jan2004
# Australia produce 1659 unità per France (CleanSkin Acne Treatment) a Feb2004
# Australia produce 1514 unità per France (CleanSkin Acne Treatment) a Mar2004
# Australia produce 1727 unità per France (CleanSkin Acne Treatment) a Apr2004
# Australia produce 1535 unità per France (CleanSkin Acne Treatment) a May2004
# Australia produce 1761 unità per France (CleanSkin Acne Treatment) a Jun2004
# Australia produce 1874 unità per France (CleanSkin Acne Treatment) a Jul2004
# Australia produce 1655 unità per France (CleanSkin Acne Treatment) a Aug2004
# Australia produce 1674 unità per France (CleanSkin Acne Treatment) a Sep2004
# Australia produce 1659 unità per France (CleanSkin Acne Treatment) a Oct2004
# Australia produce 1801 unità per France (CleanSkin Acne Treatment) a Nov2004
# Australia produce 1742 unità per France (CleanSkin Acne Treatment) a Dec2004
# Australia produce 1475 unità per France (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce
# Australia produce 666 unità per France (PurePore Insect Repellent Spray) a Jan2004
# Australia produce 611 unità per France (PurePore Insect Repellent Spray) a Feb2004
# Australia produce 698 unità per France (PurePore Insect Repellent Spray) a Mar2004
# Australia produce 747 unità per France (PurePore Insect Repellent Spray) a Apr2004
# Australia produce 694 unità per France (PurePore Insect Repellent Spray) a May2004
# Australia produce 746 unità per France (PurePore Insect Repellent Spray) a Jun2004
# Australia produce 588 unità per France (PurePore Insect Repellent Spray) a Jul2004
# Australia produce 670 unità per France (PurePore Insect Repellent Spray) a Aug2004
# Australia produce 669 unità per France (PurePore Insect Repellent Spray) a Sep2004
# Australia produce 664 unità per France (PurePore Insect Repellent Spray) a Oct2004
# Australia produce 678 unità per France (PurePore Insect Repellent Spray) a Nov2004
# Australia produce 689 unità per France (PurePore Insect Repellent Spray) a Dec2004
# Australia produce 1517 unità per India (SmilesSoPure Waterpik) a Jan2004
# Australia produce 1415 unità per India (SmilesSoPure Waterpik) a Feb2004
# Australia produce 1552 unità per India (SmilesSoPure Waterpik) a Mar2004
# Australia produce 1413 unità per India (SmilesSoPure Waterpik) a Apr2004
# Australia produce 1364 unità per India (SmilesSoPure Waterpik) a May2004
# Australia produce 1476 unità per India (SmilesSoPure Waterpik) a Jun2004
# Australia produce 1449 unità per India (SmilesSoPure Waterpik) a Jul2004
# Australia produce 1350 unità per India (SmilesSoPure Waterpik) a Aug2004
# Australia produce 1484 unità per India (SmilesSoPure Waterpik) a Sep2004
# Australia produce 1336 unità per India (SmilesSoPure Waterpik) a Oct2004
# Australia produce 1288 unità per India (SmilesSoPure Waterpik) a Nov2004
# Australia produce 1542 unità per India (SmilesSoPure Waterpik) a Dec2004
# Australia produce 1541 unità per India (CleanSkin Acne Treatment) a Jan2004
# Australia produce 1584 unità per India (CleanSkin Acne Treatment) a Feb2004
# Australia produce 1515 unità per India (CleanSkin Acne Treatment) a Mar2004
# Australia produce 1682 unità per India (CleanSkin Acne Treatment) a Apr2004
# Australia produce 1554 unità per India (CleanSkin Acne Treatment) a May2004
# Australia produce 1508 unità per India (CleanSkin Acne Treatment) a Jun2004
# Australia produce 1520 unità per India (CleanSkin Acne Treatment) a Jul2004
# Australia produce 3 unità per India (CleanSkin Acne Treatment) a Aug2004
# Australia produce 1607 unità per India (CleanSkin Acne Treatment) a Sep2004
# Australia produce 1650 unità per India (CleanSkin Acne Treatment) a Oct2004
# Australia produce 1513 unità per India (CleanSkin Acne Treatment) a Nov2004
# Australia produce 1583 unità per India (CleanSkin Acne Treatment) a Dec2004
# Australia produce 1257 unità per India (RadiantRose Baby Massage Oil) a Jan2004
# Australia produce 1162 unità per India (RadiantRose Baby Massage Oil) a Feb2004
# Australia produce 1165 unità per India (RadiantRose Baby Massage Oil) a Mar2004
# Australia produce 1177 unità per India (RadiantRose Baby Massage Oil) a Apr2004
# Australia produce 1219 unità per India (RadiantRose Baby Massage Oil) a May2004
# Australia produce 1120 unità per India (RadiantRose Baby Massage Oil) a Jun2004
# Australia produce 1106 unità per India (RadiantRose Baby Massage Oil) a Jul2004
# Australia produce 1092 unità per India (RadiantRose Baby Massage Oil) a Aug2004
# Australia produce 989 unità per India (RadiantRose Baby Massage Oil) a Sep2004
# Australia produce 1056 unità per India (RadiantRose Baby Massage Oil) a Oct2004
# Australia produce 1109 unità per India (RadiantRose Baby Massage Oil) a Nov2004
# Australia produce 967 unità per India (RadiantRose Baby Massage Oil) a Dec2004
# Australia produce 1528 unità per United Kingdom (BreatheEasy Inhalant) a Jan2004
# Australia produce 1595 unità per United Kingdom (BreatheEasy Inhalant) a Feb2004
# Australia produce 1492 unità per United Kingdom (BreatheEasy Inhalant) a Mar2004
# Australia produce 1617 unità per United Kingdom (BreatheEasy Inhalant) a Apr2004
# Australia produce 1539 unità per United Kingdom (BreatheEasy Inhalant) a May2004
# Australia produce 1530 unità per United Kingdom (BreatheEasy Inhalant) a Jun2004
# Australia produce 1541 unità per United Kingdom (BreatheEasy Inhalant) a Jul2004
# Australia produce 1460 unità per United Kingdom (BreatheEasy Inhalant) a Aug2004
# Australia produce 1578 unità per United Kingdom (BreatheEasy Inhalant) a Sep2004
# Australia produce 1697 unità per United Kingdom (BreatheEasy Inhalant) a Oct2004
# Australia produce 1526 unità per United Kingdom (BreatheEasy Inhalant) a Nov2004
# Australia produce 1506 unità per United Kingdom (BreatheEasy Inhalant) a Dec2004
# Australia produce 662 unità per United Kingdom (SmilesSoPure Waterpik) a Jan2004
# Australia produce 672 unità per United Kingdom (SmilesSoPure Waterpik) a Feb2004
# Australia produce 633 unità per United Kingdom (SmilesSoPure Waterpik) a Mar2004
# Australia produce 675 unità per United Kingdom (SmilesSoPure Waterpik) a Apr2004
# Australia produce 606 unità per United Kingdom (SmilesSoPure Waterpik) a May2004
# Australia produce 608 unità per United Kingdom (SmilesSoPure Waterpik) a Jun2004
# Australia produce 634 unità per United Kingdom (SmilesSoPure Waterpik) a Jul2004
# Australia produce 632 unità per United Kingdom (SmilesSoPure Waterpik) a Aug2004
# Australia produce 608 unità per United Kingdom (SmilesSoPure Waterpik) a Sep2004
# Australia produce 684 unità per United Kingdom (SmilesSoPure Waterpik) a Oct2004
# Australia produce 611 unità per United Kingdom (SmilesSoPure Waterpik) a Nov2004
# Australia produce 631 unità per United Kingdom (SmilesSoPure Waterpik) a Dec2004
# Australia produce 2088 unità per United Kingdom (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1928 unità per United Kingdom (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1966 unità per United Kingdom (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1932 unità per United Kingdom (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1881 unità per United Kingdom (SparklingGlow Toothpaste) a May2004
# Australia produce 2020 unità per United Kingdom (SparklingGlow Toothpaste) a Jun2004
# Australia produce 2057 unità per United Kingdom (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1778 unità per United Kingdom (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1967 unità per United Kingdom (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1101 unità per United Kingdom (PurePore Insect Repellent Spray) a Apr2004
# Australia produce 1179 unità per United Kingdom (PurePore Insect Repellent Spray) a May2004
# Australia produce 1154 unità per United Kingdom (PurePore Insect Repellent Spray) a Jun2004
# Australia produce 1115 unità per United Kingdom (PurePore Insect Repellent Spray) a Jul2004
# Australia produce 1069 unità per United Kingdom (PurePore Insect Repellent Spray) a Aug2004
# Australia produce 1196 unità per United Kingdom (PurePore Insect Repellent Spray) a Sep2004
# Australia produce 1180 unità per United Kingdom (PurePore Insect Repellent Spray) a Oct2004
# Australia produce 1295 unità per United Kingdom (PurePore Insect Repellent Spray) a Nov2004
# Australia produce 1090 unità per United Kingdom (PurePore Insect Repellent Spray) a Dec2004
# Australia produce 970 unità per Russia (SmilesSoPure Waterpik) a Jan2004
# Australia produce 934 unità per Russia (SmilesSoPure Waterpik) a Feb2004
# Australia produce 949 unità per Russia (SmilesSoPure Waterpik) a Mar2004
# Australia produce 974 unità per Russia (SmilesSoPure Waterpik) a Apr2004
# Australia produce 970 unità per Russia (SmilesSoPure Waterpik) a May2004
# Australia produce 972 unità per Russia (SmilesSoPure Waterpik) a Jun2004
# Australia produce 971 unità per Russia (SmilesSoPure Waterpik) a Jul2004
# Australia produce 972 unità per Russia (SmilesSoPure Waterpik) a Aug2004
# Australia produce 1009 unità per Russia (SmilesSoPure Waterpik) a Sep2004
# Australia produce 944 unità per Russia (SmilesSoPure Waterpik) a Oct2004
# Australia produce 1000 unità per Russia (SmilesSoPure Waterpik) a Nov2004
# Australia produce 977 unità per Russia (SmilesSoPure Waterpik) a Dec2004
# Australia produce 1505 unità per Russia (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1571 unità per Russia (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1440 unità per Russia (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1560 unità per Russia (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1511 unità per Russia (SparklingGlow Toothpaste) a May2004
# Australia produce 1484 unità per Russia (SparklingGlow Toothpaste) a Jun2004
# Australia produce 1391 unità per Russia (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1597 unità per Russia (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1699 unità per Russia (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1535 unità per Russia (SparklingGlow Toothpaste) a Oct2004
# Australia produce 1480 unità per Russia (SparklingGlow Toothpaste) a Nov2004
# Australia produce 1429 unità per Russia (SparklingGlow Toothpaste) a Dec2004
# Australia produce 447 unità per Russia (CleanSkin Acne Treatment) a Jan2004
# Australia produce 72 unità per Russia (CleanSkin Acne Treatment) a Feb2004
# Australia produce 364 unità per Russia (CleanSkin Acne Treatment) a Mar2004
# Australia produce 489 unità per Russia (CleanSkin Acne Treatment) a Apr2004
# Australia produce 461 unità per Russia (CleanSkin Acne Treatment) a May2004
# Australia produce 485 unità per Russia (CleanSkin Acne Treatment) a Jun2004
# Australia produce 463 unità per Russia (CleanSkin Acne Treatment) a Jul2004
# Australia produce 494 unità per Russia (CleanSkin Acne Treatment) a Aug2004
# Australia produce 544 unità per Russia (CleanSkin Acne Treatment) a Sep2004
# Australia produce 497 unità per Russia (CleanSkin Acne Treatment) a Oct2004
# Australia produce 499 unità per Russia (CleanSkin Acne Treatment) a Dec2004
# Australia produce 608 unità per Russia (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce
# Brazil produce 739 unità per Japan (Purezza Body Wash) a Feb2004
# Brazil produce 673 unità per Japan (Purezza Body Wash) a Mar2004
# Brazil produce 752 unità per Japan (Purezza Body Wash) a Apr2004
# Brazil produce 718 unità per Japan (Purezza Body Wash) a May2004
# Brazil produce 676 unità per Japan (Purezza Body Wash) a Jun2004
# Brazil produce 877 unità per Japan (Purezza Body Wash) a Jul2004
# Brazil produce 675 unità per Japan (Purezza Body Wash) a Aug2004
# Brazil produce 614 unità per Japan (Purezza Body Wash) a Sep2004
# Brazil produce 683 unità per Japan (Purezza Body Wash) a Oct2004
# Brazil produce 683 unità per Japan (Purezza Body Wash) a Nov2004
# Brazil produce 728 unità per Japan (Purezza Body Wash) a Dec2004
# Brazil produce 785 unità per Japan (SoftStep Baby Shampoo) a Jan2004
# Brazil produce 828 unità per Japan (SoftStep Baby Shampoo) a Feb2004
# Brazil produce 769 unità per Japan (SoftStep Baby Shampoo) a Mar2004
# Brazil produce 772 unità per Japan (SoftStep Baby Shampoo) a Apr2004
# Brazil produce 755 unità per Japan (SoftStep Baby Shampoo) a May2004
# Brazil produce 822 unità per Japan (SoftStep Baby Shampoo) a Jun2004
# ...
# United Kingdom produce 636 unità per India (FreshFusion Hair Mask) a Jan2004
# United Kingdom produce 648 unità per India (FreshFusion Hair Mask) a Feb2004
# United Kingdom produce 640 unità per India (FreshFusion Hair Mask) a Mar2004
# United Kingdom produce 603 unità per India (FreshFusion Hair Mask) a Apr2004
# United Kingdom produce 558 unità per India (FreshFusion Hair Mask) a May2004
# United Kingdom produce 610 unità per India (FreshFusion Hair Mask) a Jun2004
# United Kingdom produce 605 unità per India (FreshFusion Hair Mask) a Jul2004
# United Kingdom produce 607 unità per India (FreshFusion Hair Mask) a Aug2004
# United Kingdom produce 668 unità per India (FreshFusion Hair Mask) a Sep2004
# United Kingdom produce 618 unità per India (FreshFusion Hair Mask) a Oct2004
# United Kingdom produce 603 unità per India (FreshFusion Hair Mask) a Nov2004
# United Kingdom produce 577 unità per India (FreshFusion Hair Mask) a Dec2004
# United Kingdom produce 1786 unità per India (SmellSational Intimate Spray) a Jan2004
# United Kingdom produce 1931 unità per India (SmellSational Intimate Spray) a Feb2004
# United Kingdom produce 1821 unità per India (SmellSational Intimate Spray) a Mar2004
# United Kingdom produce 1830 unità per India (SmellSational Intimate Spray) a Apr2004
# United Kingdom produce 1809 unità per India (SmellSational Intimate Spray) a May2004
# United Kingdom produce 1759 unità per India (SmellSational Intimate Spray) a Jun2004
# United Kingdom produce 1990 unità per India (SmellSational Intimate Spray) a Jul2004
# United Kingdom produce 1630 unità per India (SmellSational Intimate Spray) a Aug2004
# United Kingdom produce 1944 unità per India (SmellSational Intimate Spray) a Sep2004
# United Kingdom produce 1801 unità per India (SmellSational Intimate Spray) a Oct2004
# United Kingdom produce 1915 unità per India (SmellSational Intimate Spray) a Nov2004
# United Kingdom produce 1922 unità per India (SmellSational Intimate Spray) a Dec2004
# United Kingdom produce 612 unità per India (RadiantRover Pet Conditioner) a Jan2004
# United Kingdom produce 823 unità per Russia (DailyDazzle Toothpaste) a Feb2004
# United Kingdom produce 805 unità per Russia (DailyDazzle Toothpaste) a Mar2004
# United Kingdom produce 818 unità per Russia (DailyDazzle Toothpaste) a Apr2004
# United Kingdom produce 975 unità per Russia (DailyDazzle Toothpaste) a May2004
# United Kingdom produce 836 unità per Russia (DailyDazzle Toothpaste) a Jun2004
# United Kingdom produce 816 unità per Russia (DailyDazzle Toothpaste) a Jul2004
# United Kingdom produce 817 unità per Russia (DailyDazzle Toothpaste) a Aug2004
# United Kingdom produce 828 unità per Russia (DailyDazzle Toothpaste) a Sep2004
# United Kingdom produce 778 unità per Russia (DailyDazzle Toothpaste) a Oct2004
# United Kingdom produce 766 unità per Russia (DailyDazzle Toothpaste) a Nov2004
# United Kingdom produce 784 unità per Russia (DailyDazzle Toothpaste) a Dec2004
# United Kingdom produce 1333 unità per Russia (OralEase Plus Toothbrush) a Jan2004
# United Kingdom produce 1437 unità per Russia (OralEase Plus Toothbrush) a Feb2004
# United Kingdom produce 1450 unità per Russia (OralEase Plus Toothbrush) a Mar2004
# United Kingdom produce 1312 unità per Russia (OralEase Plus Toothbrush) a Apr2004
# United Kingdom produce 1330 unità per Russia (OralEase Plus Toothbrush) a May2004
# United Kingdom produce 1294 unità per Russia (OralEase Plus Toothbrush) a Jun2004
# United Kingdom produce 1398 unità per Russia (OralEase Plus Toothbrush) a Jul2004
# United Kingdom produce 1390 unità per Russia (OralEase Plus Toothbrush) a Aug2004
# United Kingdom produce 1425 unità per Russia (OralEase Plus Toothbrush) a Sep2004
# United Kingdom produce 1403 unità per Russia (OralEase Plus Toothbrush) a Oct2004
# United Kingdom produce 1342 unità per Russia (OralEase Plus Toothbrush) a Nov2004
# United Kingdom produce 1264 unità per Russia (OralEase Plus Toothbrush) a Dec2004
# United Kingdom produce 1165 unità per Russia (FreshFusion Hair Mask) a Jan2004
# United Kingdom produce 1231 unità per Russia (FreshFusion Hair Mask) a Feb2004
# United Kingdom produce 1307 unità per Russia (FreshFusion Hair Mask) a Mar2004
# United Kingdom produce 1281 unità per Russia (FreshFusion Hair Mask) a Apr2004
# United Kingdom produce 1312 unità per Russia (FreshFusion Hair Mask) a May2004
# United Kingdom produce 1277 unità per Russia (FreshFusion Hair Mask) a Jun2004
# United Kingdom produce 1317 unità per Russia (FreshFusion Hair Mask) a Jul2004
# United Kingdom produce 1221 unità per Russia (FreshFusion Hair Mask) a Aug2004
# United Kingdom produce 1269 unità per Russia (FreshFusion Hair Mask) a Sep2004
# United Kingdom produce 1258 unità per Russia (FreshFusion Hair Mask) a Oct2004
# United Kingdom produce 1298 unità per Russia (FreshFusion Hair Mask) a Nov2004
# United Kingdom produce 1211 unità per Russia (FreshFusion Hair Mask) a Dec2004
# United Kingdom produce 601 unità per Russia (SmellSational Intimate Spray) a Jan2004
# United Kingdom produce 597 unità per Russia (SmellSational Intimate Spray) a Feb2004
# United Kingdom produce 659 unità per Russia (SmellSational Intimate Spray) a Mar2004
# United Kingdom produce 659 unità per Russia (SmellSational Intimate Spray) a Apr2004
# United Kingdom produce 604 unità per Russia (SmellSational Intimate Spray) a May2004
# United Kingdom produce 612 unità per Russia (SmellSational Intimate Spray) a Jun2004
# United Kingdom produce 654 unità per Russia (SmellSational Intimate Spray) a Jul2004
# United Kingdom produce 512 unità per Russia (SmellSational Intimate Spray) a Aug2004
# United Kingdom produce 658 unità per Russia (SmellSational Intimate Spray) a Sep2004
# United Kingdom produce 755 unità per Russia (SmellSational Intimate Spray) a Oct2004
# United Kingdom produce 718 unità per Russia (SmellSational Intimate Spray) a Nov2004
# United Kingdom produce 614 unità per Russia (SmellSational Intimate Spray) a Dec2004
# United Kingdom produce 1822 unità per Russia (FreshFusion All-Purpose Cleaner) a Jan2004
# United Kingdom produce 1997 unità per Russia (FreshFusion All-Purpose Cleaner) a Feb2004
# United Kingdom produce 1795 unità per Russia (FreshFusion All-Purpose Cleaner) a Mar2004
# United Kingdom produce 1881 unità per Russia (FreshFusion All-Purpose Cleaner) a Apr2004
# United Kingdom produce 1839 unità per Russia (FreshFusion All-Purpose Cleaner) a May2004
# United Kingdom produce 1908 unità per Russia (FreshFusion All-Purpose Cleaner) a Jun2004
# United Kingdom produce 1913 unità per Russia (FreshFusion All-Purpose Cleaner) a Jul2004
# United Kingdom produce 1680 unità per Russia (FreshFusion All-Purpose Cleaner) a Aug2004
# United Kingdom produce 1761 unità per Russia (FreshFusion All-Purpose Cleaner) a Sep2004
# United Kingdom produce 1895 unità per Russia (FreshFusion All-Purpose Cleaner) a Oct2004
# United Kingdom produce 1836 unità per Russia (FreshFusion All-Purpose Cleaner) a Nov2004
# United Kingdom produce 1748 unità per Russia (FreshFusion All-Purpose Cleaner) a Dec2004
# United Kingdom produce 667 unità per Russia (BrightBreeze Pet Odor Eliminator) a Jan2004
# United Kingdom produce 622 unità per Russia (BrightBreeze Pet Odor Eliminator) a Feb2004
# United Kingdom produce 597 unità per Russia (BrightBreeze Pet Odor Eliminator) a Mar2004
# United Kingdom produce 905 unità per Russia (BrightBreeze Pet Odor Eliminator) a Apr2004
# United Kingdom produce 665 unità per Russia (BrightBreeze Pet Odor Eliminator) a May2004
# United Kingdom produce 695 unità per Russia (BrightBreeze Pet Odor Eliminator) a Jun2004
# United Kingdom produce 643 unità per Russia (BrightBreeze Pet Odor Eliminator) a Jul2004
# United Kingdom produce 821 unità per Russia (BrightBreeze Pet Odor Eliminator) a Aug2004
# United Kingdom produce 684 unità per Russia (BrightBreeze Pet Odor Eliminator) a Sep2004
# United Kingdom produce 623 unità per Russia (BrightBreeze Pet Odor Eliminator) a Oct2004
# United Kingdom produce 547 unità per Russia (BrightBreeze Pet Odor Eliminator) a Nov2004
# United Kingdom produce 835 unità per Russia (BrightBreeze Pet Odor Eliminator) a Dec2004

# %%
# initialize two dataframes for the solution
# production_plan = pd.DataFrame(columns=['Country', 'Product', 'Month', 'Quantity'])
# shipment_plan = pd.DataFrame(columns=['Origin', 'Destination', 'Product', 'Month', 'Quantity'])

shipment_data = []

# fill the production_plan dataframe with the results
for (i, j, p, m), var in x.items():
	shipment_data.append({
        'Origin': i,
		'Destination': j,
		'Product': p,
		'Month': m,
		'Quantity': int(var.solution_value())
	})
    
shipment_plan = pd.DataFrame(shipment_data)

# %%
shipment_plan[(~(shipment_plan['Origin'] == shipment_plan['Destination'])) & (shipment_plan['Quantity'] > 0)].reset_index(drop=True)
# Out:
#               Origin Destination                           Product    Month  \
# 0          Australia       Japan              BreatheEasy Inhalant  Jan2004
# 1          Australia       Japan              BreatheEasy Inhalant  Feb2004
# 2          Australia       Japan              BreatheEasy Inhalant  Mar2004
# 3          Australia       Japan              BreatheEasy Inhalant  Apr2004
# 4          Australia       Japan              BreatheEasy Inhalant  May2004
# ...              ...         ...                               ...      ...
# 6651  United Kingdom      Russia  BrightBreeze Pet Odor Eliminator  Aug2004
# 6652  United Kingdom      Russia  BrightBreeze Pet Odor Eliminator  Sep2004
# 6653  United Kingdom      Russia  BrightBreeze Pet Odor Eliminator  Oct2004
# 6654  United Kingdom      Russia  BrightBreeze Pet Odor Eliminator  Nov2004
# 6655  United Kingdom      Russia  BrightBreeze Pet Odor Eliminator  Dec2004
#
#       Quantity
# 0         1160
# 1         1187
# 2         1056
# 3         1134
# 4         1134
# ...        ...
# 6651       821
# 6652       684
# 6653       623
# 6654       547
# 6655       835
#
# [6656 rows x 5 columns]

# %%
A = df_target.groupby(['Product']).agg({'Quantity': 'sum'}).reset_index()
B = shipment_plan.groupby(['Product']).agg({'Quantity': 'sum'}).reset_index()
A['Quantity'] - B['Quantity']
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: Quantity, Length: 100, dtype: int64

# %%
production_plan = shipment_plan.groupby(['Origin', 'Product', 'Month'], as_index=False).agg({'Quantity': 'sum'})
production_plan.rename(columns={'Origin': 'Country'}, inplace=True)
production_plan.to_csv('outputs/03_output_productionPlan_1239.csv', index=False)
shipment_plan.to_csv('outputs/03_output_shipments_1239.csv', index=False)

# %% [markdown]
# # Without symmetric shipment

# %%
import numpy as np
cost_matrix = df_shipment_cost.pivot_table(index="Origin", columns="Destination", values="Unit Cost")

# Optional: Fill NaN with a value if needed, like 0 or np.inf
# cost_matrix = cost_matrix.fillna(0)
cost_matrix.loc["Russia"] = pd.NA
# insert the Japan column and fill with NA
cost_matrix.loc[:, "Japan"] = pd.NA
# Rearange the rows in the order of the columns
cost_matrix = cost_matrix.reindex(columns=cost_matrix.columns, index=cost_matrix.index)
# Fill the NAN with infinity
# cost_matrix = cost_matrix.fillna(float(np.inf))
# Fill Nan with symmetric values
cost_matrix = cost_matrix.fillna(cost_matrix.T)
#print(cost_matrix.columns.values)
# print(cost_matrix)
# Fill the elements with same origin and destination by name with zero
for i in cost_matrix.columns.values:
	cost_matrix.loc[i, i] = 0
#print(cost_matrix)

# Rearange to a single dataframe
cost_matrix = cost_matrix.stack().reset_index()
cost_matrix.columns = ['Origin', 'Destination', 'Unit Cost']
cost_matrix.head(20)
# Out:
# /tmp/ipykernel_38991/324858150.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cost_matrix.loc["Russia"] = pd.NA
#        Origin     Destination Unit Cost
# 0   Australia       Australia         0
# 1   Australia          Brazil     10.07
# 2   Australia           Egypt      8.89
# 3   Australia          France     10.61
# 4   Australia           India      7.78
# 5   Australia           Italy      8.35
# 6   Australia          Russia     11.06
# 7   Australia    South Africa     13.61
# 8   Australia  United Kingdom      9.33
# 9   Australia           Japan     13.43
# 10     Brazil       Australia     10.07
# 11     Brazil          Brazil         0
# 12     Brazil           Egypt     10.35
# 13     Brazil          France      9.15
# 14     Brazil           India     10.28
# 15     Brazil           Italy      8.28
# 16     Brazil          Russia      11.9
# 17     Brazil    South Africa     10.39
# 18     Brazil  United Kingdom       7.3
# 19     Brazil           Japan     10.42

# %%
import pandas as pd
from ortools.linear_solver import pywraplp

# Carica i dataset necessari
demand_df = df_target       # Country, Product, Month, Quantity
capacity_df = df_capacity     # Country, Monthly Capacity
shipment_cost_df = df_shipment_cost 
# shipment_cost_df = cost_matrix # Origin, Destination, Cost_per_Unit
production_cost_df = df_production_cost # Country, Product, Cost_per_Unit

# Prepara dizionari
demand_df['Key'] = list(zip(demand_df['Country'], demand_df['Product'], demand_df['Month']))
demand = dict(zip(demand_df['Key'], demand_df['Quantity']))

capacity = dict(zip(capacity_df['Country'], capacity_df['Monthly Capacity']))

# Creiamo un dizionario per i costi di trasporto
transport_costs = {}
for _, row in shipment_cost_df.iterrows():
    key = (row['Origin'], row['Destination'])
    transport_costs[key] = row['Unit Cost']
    # key_inf = (row['Destination'], row['Origin'])
    # transport_costs[key] = np.inf
print(transport_costs)

# Creiamo un dizionario per i costi di produzione
production_costs = {}
for _, row in production_cost_df.iterrows():
    key = (row['Country'], row['Product'])
    production_costs[key] = row['Unit Cost']

# Impianti e mesi
plants = list(capacity.keys())
months = sorted(demand_df['Month'].unique())
demand_keys = list(demand.keys())

# Inizializza il solver OR-Tools
solver = pywraplp.Solver.CreateSolver('SAT')

# Variabili decisionali: quanto produce ogni impianto per soddisfare domanda (i,j,p,m)
x = {}
for i in plants:
    for (j, p, m) in demand_keys:
        x[i, j, p, m] = solver.NumVar(0, solver.infinity(), f'x_{i}_{j}_{p}_{m}')

# Variabile per il massimo carico (da minimizzare)
max_load = solver.NumVar(0, 1, 'max_load')

# 1. Vincolo di domanda
for (j, p, m) in demand_keys:
    solver.Add(solver.Sum(x[i, j, p, m] for i in plants) == demand[(j, p, m)])

# 2. Vincoli di capacità impianto
for i in plants:
    for m in months:
        monthly_prod = solver.Sum(x[i, j, p, m] for (j, p, m2) in demand_keys if m2 == m)
        solver.Add(monthly_prod <= capacity[i])

# 3. Vincoli per il carico massimo
for i in plants:
    for m in months:
        monthly_prod = solver.Sum(x[i, j, p, m] for (j, p, m2) in demand_keys if m2 == m)
        solver.Add(monthly_prod <= max_load * capacity[i])

# 4. Funzione obiettivo: Minimizzare i costi di produzione e trasporto
total_cost = solver.Sum(
    # x[i, j, p, m] * transport_costs.get((i, j), 0) # Costo di trasporto se lo trova, sennò 0
    # x[i, j, p, m] * transport_costs.get((i, j), np.inf) # Costo di trasporto se lo trova, sennò infinito
    x[i, j, p, m] * transport_costs.get((i, j), transport_costs.get((j,i))) if i !=j else 0 # Costo di trasporto se lo trova, sennò simmetrico
    for i in plants for (j, p, m) in demand_keys
)

# Aggiungi i costi di produzione alla funzione obiettivo
total_cost += solver.Sum(
    x[i, j, p, m] * production_costs.get((i, p), 0)  # Costo di produzione se lo trova, sennò 0
    for i in plants for (j, p, m) in demand_keys
)

# Aggiungi l'obiettivo (costo totale da minimizzare)
solver.Minimize(total_cost*1e-8 + max_load)

# Risoluzione
status = solver.Solve()

# Output della soluzione
if status == pywraplp.Solver.OPTIMAL:
    print(f"Status: Ottimale")
    print(f"Carico massimo usato: {max_load.solution_value():.2%}")
    print("Costi totali:", solver.Objective().Value())
    
    # Crea due liste separate per il piano di produzione e quello di spedizione
    production_data = []
    shipment_data = []

if status == pywraplp.Solver.OPTIMAL:
    print(f'Status: Ottimale\nCarico massimo usato: {max_load.solution_value():.2%}')
    for (i, j, p, m), var in x.items():
        if var.solution_value() > 0:
            print(f'{i} produce {var.solution_value():.0f} unità per {j} ({p}) a {m}')
else:
    print('Nessuna soluzione ottimale trovata.')
# Out:
# {('Japan', 'Australia'): 13.43, ('Japan', 'Brazil'): 10.42, ('Japan', 'Egypt'): 9.9, ('Japan', 'Italy'): 13.01, ('Japan', 'South Africa'): 8.92, ('Japan', 'France'): 5.6, ('Japan', 'India'): 6.75, ('Japan', 'United Kingdom'): 10.12, ('Japan', 'Russia'): 12.6, ('Australia', 'Brazil'): 10.07, ('Australia', 'Egypt'): 8.89, ('Australia', 'Italy'): 8.35, ('Australia', 'South Africa'): 13.61, ('Australia', 'France'): 10.61, ('Australia', 'India'): 7.78, ('Australia', 'United Kingdom'): 9.33, ('Australia', 'Russia'): 11.06, ('Brazil', 'Egypt'): 10.35, ('Brazil', 'Italy'): 8.28, ('Brazil', 'South Africa'): 10.39, ('Brazil', 'France'): 9.15, ('Brazil', 'India'): 10.28, ('Brazil', 'United Kingdom'): 7.3, ('Brazil', 'Russia'): 11.9, ('Egypt', 'Italy'): 10.86, ('Egypt', 'South Africa'): 9.72, ('Egypt', 'France'): 10.98, ('Egypt', 'India'): 11.43, ('Egypt', 'United Kingdom'): 8.9, ('Egypt', 'Russia'): 8.51, ('Italy', 'South Africa'): 12.76, ('Italy', 'France'): 8.42, ('Italy', 'India'): 10.82, ('Italy', 'United Kingdom'): 9.42, ('Italy', 'Russia'): 9.3, ('South Africa', 'France'): 9.98, ('South Africa', 'India'): 8.91, ('South Africa', 'United Kingdom'): 8.8, ('South Africa', 'Russia'): 10.81, ('France', 'India'): 12.11, ('France', 'United Kingdom'): 9.49, ('France', 'Russia'): 9.45, ('India', 'United Kingdom'): 6.87, ('India', 'Russia'): 8.97, ('United Kingdom', 'Russia'): 13.01}
# Status: Ottimale
# Carico massimo usato: 100.00%
# Costi totali: 2.0758116483000046
# Status: Ottimale
# Carico massimo usato: 100.00%
# Australia produce 1326 unità per Japan (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce 1299 unità per Japan (SoothingSerenity Hand Sanitizer) a Feb2004
# Australia produce 1332 unità per Japan (SoothingSerenity Hand Sanitizer) a Mar2004
# Australia produce 1376 unità per Japan (SoothingSerenity Hand Sanitizer) a Apr2004
# Australia produce 1313 unità per Japan (SoothingSerenity Hand Sanitizer) a May2004
# Australia produce 1283 unità per Japan (SoothingSerenity Hand Sanitizer) a Jun2004
# Australia produce 1296 unità per Japan (SoothingSerenity Hand Sanitizer) a Jul2004
# Australia produce 1256 unità per Japan (SoothingSerenity Hand Sanitizer) a Aug2004
# Australia produce 1200 unità per Japan (SoothingSerenity Hand Sanitizer) a Sep2004
# Australia produce 1434 unità per Japan (SoothingSerenity Hand Sanitizer) a Oct2004
# Australia produce 1242 unità per Japan (SoothingSerenity Hand Sanitizer) a Nov2004
# Australia produce 1335 unità per Japan (SoothingSerenity Hand Sanitizer) a Dec2004
# Australia produce 772 unità per Australia (MorningMint) a Jan2004
# Australia produce 822 unità per Australia (MorningMint) a Feb2004
# Australia produce 1043 unità per Australia (MorningMint) a Mar2004
# Australia produce 882 unità per Australia (MorningMint) a Apr2004
# Australia produce 807 unità per Australia (MorningMint) a May2004
# Australia produce 835 unità per Australia (MorningMint) a Jun2004
# Australia produce 792 unità per Australia (MorningMint) a Jul2004
# Australia produce 796 unità per Australia (MorningMint) a Aug2004
# Australia produce 959 unità per Australia (MorningMint) a Sep2004
# Australia produce 825 unità per Australia (MorningMint) a Oct2004
# Australia produce 838 unità per Australia (MorningMint) a Nov2004
# Australia produce 762 unità per Australia (MorningMint) a Dec2004
# Australia produce 1768 unità per Australia (SmileShield Whitening Strips) a Jan2004
# Australia produce 1609 unità per Australia (SmileShield Whitening Strips) a Feb2004
# Australia produce 1523 unità per Australia (SmileShield Whitening Strips) a Mar2004
# Australia produce 1667 unità per Australia (SmileShield Whitening Strips) a Apr2004
# Australia produce 1743 unità per Australia (SmileShield Whitening Strips) a May2004
# Australia produce 1685 unità per Australia (SmileShield Whitening Strips) a Jun2004
# Australia produce 1639 unità per Australia (SmileShield Whitening Strips) a Jul2004
# Australia produce 1665 unità per Australia (SmileShield Whitening Strips) a Aug2004
# Australia produce 1630 unità per Australia (SmileShield Whitening Strips) a Sep2004
# Australia produce 1696 unità per Australia (SmileShield Whitening Strips) a Oct2004
# Australia produce 1704 unità per Australia (SmileShield Whitening Strips) a Nov2004
# Australia produce 1766 unità per Australia (SmileShield Whitening Strips) a Dec2004
# Australia produce 952 unità per Australia (BriteBite Toothbrush) a Jan2004
# Australia produce 1131 unità per Australia (BriteBite Toothbrush) a Feb2004
# Australia produce 1083 unità per Australia (BriteBite Toothbrush) a Mar2004
# Australia produce 1016 unità per Australia (BriteBite Toothbrush) a Apr2004
# Australia produce 1032 unità per Australia (BriteBite Toothbrush) a May2004
# Australia produce 1061 unità per Australia (BriteBite Toothbrush) a Jun2004
# Australia produce 1044 unità per Australia (BriteBite Toothbrush) a Jul2004
# Australia produce 1124 unità per Australia (BriteBite Toothbrush) a Aug2004
# Australia produce 1030 unità per Australia (BriteBite Toothbrush) a Sep2004
# Australia produce 1176 unità per Australia (BriteBite Toothbrush) a Oct2004
# Australia produce 1047 unità per Australia (BriteBite Toothbrush) a Nov2004
# Australia produce 1070 unità per Australia (BriteBite Toothbrush) a Dec2004
# Australia produce 1631 unità per Australia (CleanSlate Mouthwash) a Jan2004
# Australia produce 1756 unità per Australia (CleanSlate Mouthwash) a Feb2004
# Australia produce 1595 unità per Australia (CleanSlate Mouthwash) a Mar2004
# Australia produce 1703 unità per Australia (CleanSlate Mouthwash) a Apr2004
# Australia produce 1687 unità per Australia (CleanSlate Mouthwash) a May2004
# Australia produce 1644 unità per Australia (CleanSlate Mouthwash) a Jun2004
# Australia produce 1713 unità per Australia (CleanSlate Mouthwash) a Jul2004
# Australia produce 1671 unità per Australia (CleanSlate Mouthwash) a Aug2004
# Australia produce 1528 unità per Australia (CleanSlate Mouthwash) a Sep2004
# Australia produce 1492 unità per Australia (CleanSlate Mouthwash) a Oct2004
# Australia produce 1700 unità per Australia (CleanSlate Mouthwash) a Nov2004
# Australia produce 1886 unità per Australia (CleanSlate Mouthwash) a Dec2004
# Australia produce 645 unità per Australia (DailyDazzle Toothpaste) a Jan2004
# Australia produce 700 unità per Australia (DailyDazzle Toothpaste) a Feb2004
# Australia produce 656 unità per Australia (DailyDazzle Toothpaste) a Mar2004
# Australia produce 713 unità per Australia (DailyDazzle Toothpaste) a Apr2004
# Australia produce 733 unità per Australia (DailyDazzle Toothpaste) a May2004
# Australia produce 710 unità per Australia (DailyDazzle Toothpaste) a Jun2004
# Australia produce 714 unità per Australia (DailyDazzle Toothpaste) a Jul2004
# Australia produce 706 unità per Australia (DailyDazzle Toothpaste) a Aug2004
# Australia produce 705 unità per Australia (DailyDazzle Toothpaste) a Sep2004
# Australia produce 704 unità per Australia (DailyDazzle Toothpaste) a Oct2004
# Australia produce 736 unità per Australia (DailyDazzle Toothpaste) a Nov2004
# Australia produce 685 unità per Australia (DailyDazzle Toothpaste) a Dec2004
# Australia produce 1867 unità per Australia (BreatheEasy Inhalant) a Jan2004
# Australia produce 1675 unità per Australia (BreatheEasy Inhalant) a Feb2004
# Australia produce 1721 unità per Australia (BreatheEasy Inhalant) a Mar2004
# Australia produce 1957 unità per Australia (BreatheEasy Inhalant) a Apr2004
# Australia produce 1904 unità per Australia (BreatheEasy Inhalant) a May2004
# Australia produce 1928 unità per Australia (BreatheEasy Inhalant) a Jun2004
# Australia produce 1789 unità per Australia (BreatheEasy Inhalant) a Jul2004
# Australia produce 1827 unità per Australia (BreatheEasy Inhalant) a Aug2004
# Australia produce 1929 unità per Australia (BreatheEasy Inhalant) a Sep2004
# Australia produce 1652 unità per Australia (BreatheEasy Inhalant) a Oct2004
# Australia produce 2034 unità per Australia (BreatheEasy Inhalant) a Nov2004
# Australia produce 1699 unità per Australia (BreatheEasy Inhalant) a Dec2004
# Australia produce 621 unità per Australia (FreshFix Mouthwash) a Jan2004
# Australia produce 675 unità per Australia (FreshFix Mouthwash) a Feb2004
# Australia produce 625 unità per Australia (FreshFix Mouthwash) a Mar2004
# Australia produce 561 unità per Australia (FreshFix Mouthwash) a Apr2004
# Australia produce 651 unità per Australia (FreshFix Mouthwash) a May2004
# Australia produce 621 unità per Australia (FreshFix Mouthwash) a Jun2004
# Australia produce 621 unità per Australia (FreshFix Mouthwash) a Jul2004
# Australia produce 639 unità per Australia (FreshFix Mouthwash) a Aug2004
# Australia produce 582 unità per Australia (FreshFix Mouthwash) a Sep2004
# Australia produce 618 unità per Australia (FreshFix Mouthwash) a Oct2004
# Australia produce 619 unità per Australia (FreshFix Mouthwash) a Nov2004
# Australia produce 667 unità per Australia (FreshFix Mouthwash) a Dec2004
# Australia produce 1324 unità per Australia (SparklingGlow Toothpaste) a Jan2004
# Australia produce 1242 unità per Australia (SparklingGlow Toothpaste) a Feb2004
# Australia produce 1324 unità per Australia (SparklingGlow Toothpaste) a Mar2004
# Australia produce 1381 unità per Australia (SparklingGlow Toothpaste) a Apr2004
# Australia produce 1202 unità per Australia (SparklingGlow Toothpaste) a May2004
# Australia produce 1385 unità per Australia (SparklingGlow Toothpaste) a Jun2004
# Australia produce 1272 unità per Australia (SparklingGlow Toothpaste) a Jul2004
# Australia produce 1311 unità per Australia (SparklingGlow Toothpaste) a Aug2004
# Australia produce 1321 unità per Australia (SparklingGlow Toothpaste) a Sep2004
# Australia produce 1262 unità per Australia (SparklingGlow Toothpaste) a Oct2004
# Australia produce 1256 unità per Australia (SparklingGlow Toothpaste) a Nov2004
# Australia produce 1231 unità per Australia (SparklingGlow Toothpaste) a Dec2004
# Australia produce 1506 unità per Australia (Purezza Body Wash) a Jan2004
# Australia produce 1271 unità per Australia (Purezza Body Wash) a Feb2004
# Australia produce 1253 unità per Australia (Purezza Body Wash) a Mar2004
# Australia produce 1275 unità per Australia (Purezza Body Wash) a Apr2004
# Australia produce 1349 unità per Australia (Purezza Body Wash) a May2004
# Australia produce 1299 unità per Australia (Purezza Body Wash) a Jun2004
# Australia produce 1340 unità per Australia (Purezza Body Wash) a Jul2004
# Australia produce 1446 unità per Australia (Purezza Body Wash) a Aug2004
# Australia produce 1215 unità per Australia (Purezza Body Wash) a Sep2004
# Australia produce 1218 unità per Australia (Purezza Body Wash) a Oct2004
# Australia produce 1411 unità per Australia (Purezza Body Wash) a Nov2004
# Australia produce 1297 unità per Australia (Purezza Body Wash) a Dec2004
# Australia produce 1776 unità per Australia (GentleGlow Face Lotion) a Jan2004
# Australia produce 1773 unità per Australia (GentleGlow Face Lotion) a Feb2004
# Australia produce 1889 unità per Australia (GentleGlow Face Lotion) a Mar2004
# Australia produce 1885 unità per Australia (GentleGlow Face Lotion) a Apr2004
# Australia produce 1628 unità per Australia (GentleGlow Face Lotion) a May2004
# Australia produce 1802 unità per Australia (GentleGlow Face Lotion) a Jun2004
# Australia produce 1938 unità per Australia (GentleGlow Face Lotion) a Jul2004
# Australia produce 1834 unità per Australia (GentleGlow Face Lotion) a Aug2004
# Australia produce 1983 unità per Australia (GentleGlow Face Lotion) a Sep2004
# Australia produce 2011 unità per Australia (GentleGlow Face Lotion) a Oct2004
# Australia produce 1841 unità per Australia (GentleGlow Face Lotion) a Nov2004
# Australia produce 1972 unità per Australia (GentleGlow Face Lotion) a Dec2004
# Australia produce 1699 unità per Australia (HydraHydrate Hand Cream) a Jan2004
# Australia produce 1868 unità per Australia (HydraHydrate Hand Cream) a Feb2004
# Australia produce 1765 unità per Australia (HydraHydrate Hand Cream) a Mar2004
# Australia produce 1778 unità per Australia (HydraHydrate Hand Cream) a Apr2004
# Australia produce 1936 unità per Australia (HydraHydrate Hand Cream) a May2004
# Australia produce 1767 unità per Australia (HydraHydrate Hand Cream) a Jun2004
# Australia produce 1741 unità per Australia (HydraHydrate Hand Cream) a Jul2004
# Australia produce 1997 unità per Australia (HydraHydrate Hand Cream) a Aug2004
# Australia produce 1905 unità per Australia (HydraHydrate Hand Cream) a Sep2004
# Australia produce 1804 unità per Australia (HydraHydrate Hand Cream) a Oct2004
# Australia produce 1658 unità per Australia (HydraHydrate Hand Cream) a Nov2004
# Australia produce 1873 unità per Australia (HydraHydrate Hand Cream) a Dec2004
# Australia produce 722 unità per Australia (SilkSmooth Exfoliating Scrub) a Jan2004
# Australia produce 781 unità per Australia (SilkSmooth Exfoliating Scrub) a Feb2004
# Australia produce 782 unità per Australia (SilkSmooth Exfoliating Scrub) a Mar2004
# Australia produce 784 unità per Australia (SilkSmooth Exfoliating Scrub) a Apr2004
# Australia produce 775 unità per Australia (SilkSmooth Exfoliating Scrub) a May2004
# Australia produce 715 unità per Australia (SilkSmooth Exfoliating Scrub) a Jun2004
# Australia produce 797 unità per Australia (SilkSmooth Exfoliating Scrub) a Jul2004
# Australia produce 782 unità per Australia (SilkSmooth Exfoliating Scrub) a Aug2004
# Australia produce 724 unità per Australia (SilkSmooth Exfoliating Scrub) a Sep2004
# Australia produce 779 unità per Australia (SilkSmooth Exfoliating Scrub) a Oct2004
# Australia produce 763 unità per Australia (SilkSmooth Exfoliating Scrub) a Nov2004
# Australia produce 669 unità per Australia (SilkSmooth Exfoliating Scrub) a Dec2004
# Australia produce 683 unità per Australia (Refreshing Rose Body Oil) a Jan2004
# Australia produce 728 unità per Australia (Refreshing Rose Body Oil) a Feb2004
# Australia produce 901 unità per Australia (Refreshing Rose Body Oil) a Mar2004
# Australia produce 698 unità per Australia (Refreshing Rose Body Oil) a Apr2004
# Australia produce 901 unità per Australia (Refreshing Rose Body Oil) a May2004
# Australia produce 751 unità per Australia (Refreshing Rose Body Oil) a Jun2004
# Australia produce 641 unità per Australia (Refreshing Rose Body Oil) a Jul2004
# Australia produce 754 unità per Australia (Refreshing Rose Body Oil) a Aug2004
# Australia produce 775 unità per Australia (Refreshing Rose Body Oil) a Sep2004
# Australia produce 710 unità per Australia (Refreshing Rose Body Oil) a Oct2004
# Australia produce 835 unità per Australia (Refreshing Rose Body Oil) a Nov2004
# Australia produce 703 unità per Australia (Refreshing Rose Body Oil) a Dec2004
# Australia produce 616 unità per Australia (RadiantRose Face Mask) a Jan2004
# Australia produce 658 unità per Australia (RadiantRose Face Mask) a Feb2004
# Australia produce 552 unità per Australia (RadiantRose Face Mask) a Mar2004
# Australia produce 603 unità per Australia (RadiantRose Face Mask) a Apr2004
# Australia produce 576 unità per Australia (RadiantRose Face Mask) a May2004
# Australia produce 623 unità per Australia (RadiantRose Face Mask) a Jun2004
# Australia produce 626 unità per Australia (RadiantRose Face Mask) a Jul2004
# Australia produce 617 unità per Australia (RadiantRose Face Mask) a Aug2004
# Australia produce 586 unità per Australia (RadiantRose Face Mask) a Sep2004
# Australia produce 628 unità per Australia (RadiantRose Face Mask) a Oct2004
# Australia produce 576 unità per Australia (RadiantRose Face Mask) a Nov2004
# Australia produce 618 unità per Australia (RadiantRose Face Mask) a Dec2004
# Australia produce 1088 unità per Australia (GentleGlow Face Cleanser) a Jan2004
# Australia produce 1092 unità per Australia (GentleGlow Face Cleanser) a Feb2004
# Australia produce 965 unità per Australia (GentleGlow Face Cleanser) a Mar2004
# Australia produce 1053 unità per Australia (GentleGlow Face Cleanser) a Apr2004
# Australia produce 1043 unità per Australia (GentleGlow Face Cleanser) a May2004
# Australia produce 1071 unità per Australia (GentleGlow Face Cleanser) a Jun2004
# Australia produce 1108 unità per Australia (GentleGlow Face Cleanser) a Jul2004
# Australia produce 1094 unità per Australia (GentleGlow Face Cleanser) a Aug2004
# Australia produce 1044 unità per Australia (GentleGlow Face Cleanser) a Sep2004
# Australia produce 1026 unità per Australia (GentleGlow Face Cleanser) a Oct2004
# Australia produce 1023 unità per Australia (GentleGlow Face Cleanser) a Nov2004
# Australia produce 1014 unità per Australia (GentleGlow Face Cleanser) a Dec2004
# Australia produce 827 unità per Australia (PurePore Toner) a Jan2004
# Australia produce 684 unità per Australia (PurePore Toner) a Feb2004
# Australia produce 811 unità per Australia (PurePore Toner) a Mar2004
# Australia produce 833 unità per Australia (PurePore Toner) a Apr2004
# Australia produce 823 unità per Australia (PurePore Toner) a May2004
# Australia produce 733 unità per Australia (PurePore Toner) a Jun2004
# Australia produce 710 unità per Australia (PurePore Toner) a Jul2004
# Australia produce 832 unità per Australia (PurePore Toner) a Aug2004
# Australia produce 795 unità per Australia (PurePore Toner) a Sep2004
# Australia produce 786 unità per Australia (PurePore Toner) a Oct2004
# Australia produce 821 unità per Australia (PurePore Toner) a Nov2004
# Australia produce 749 unità per Australia (PurePore Toner) a Dec2004
# Australia produce 1459 unità per Australia (MorningMist Deodorant) a Jan2004
# Australia produce 1219 unità per Australia (MorningMist Deodorant) a Feb2004
# Australia produce 1445 unità per Australia (MorningMist Deodorant) a Mar2004
# Australia produce 1479 unità per Australia (MorningMist Deodorant) a Apr2004
# Australia produce 1420 unità per Australia (MorningMist Deodorant) a May2004
# Australia produce 1484 unità per Australia (MorningMist Deodorant) a Jun2004
# Australia produce 1416 unità per Australia (MorningMist Deodorant) a Jul2004
# Australia produce 1454 unità per Australia (MorningMist Deodorant) a Aug2004
# Australia produce 1407 unità per Australia (MorningMist Deodorant) a Sep2004
# Australia produce 1534 unità per Australia (MorningMist Deodorant) a Oct2004
# Australia produce 1329 unità per Australia (MorningMist Deodorant) a Nov2004
# Australia produce 1373 unità per Australia (MorningMist Deodorant) a Dec2004
# Australia produce 958 unità per Australia (CleanSlate Stain Remover) a Jan2004
# Australia produce 904 unità per Australia (CleanSlate Stain Remover) a Feb2004
# Australia produce 975 unità per Australia (CleanSlate Stain Remover) a Mar2004
# Australia produce 1038 unità per Australia (CleanSlate Stain Remover) a Apr2004
# Australia produce 913 unità per Australia (CleanSlate Stain Remover) a May2004
# Australia produce 932 unità per Australia (CleanSlate Stain Remover) a Jun2004
# Australia produce 1025 unità per Australia (CleanSlate Stain Remover) a Jul2004
# Australia produce 998 unità per Australia (CleanSlate Stain Remover) a Aug2004
# Australia produce 894 unità per Australia (CleanSlate Stain Remover) a Sep2004
# Australia produce 937 unità per Australia (CleanSlate Stain Remover) a Oct2004
# Australia produce 927 unità per Australia (CleanSlate Stain Remover) a Nov2004
# Australia produce 916 unità per Australia (CleanSlate Stain Remover) a Dec2004
# Australia produce 1904 unità per Australia (SoothingSoft Fabric Softener) a Jan2004
# Australia produce 1931 unità per Australia (SoothingSoft Fabric Softener) a Feb2004
# Australia produce 1880 unità per Australia (SoothingSoft Fabric Softener) a Mar2004
# Australia produce 1880 unità per Australia (SoothingSoft Fabric Softener) a Apr2004
# Australia produce 1758 unità per Australia (SoothingSoft Fabric Softener) a May2004
# Australia produce 1804 unità per Australia (SoothingSoft Fabric Softener) a Jun2004
# Australia produce 1785 unità per Australia (SoothingSoft Fabric Softener) a Jul2004
# Australia produce 1889 unità per Australia (SoothingSoft Fabric Softener) a Aug2004
# Australia produce 1806 unità per Australia (SoothingSoft Fabric Softener) a Sep2004
# Australia produce 1848 unità per Australia (SoothingSoft Fabric Softener) a Oct2004
# Australia produce 1977 unità per Australia (SoothingSoft Fabric Softener) a Nov2004
# Australia produce 1833 unità per Australia (SoothingSoft Fabric Softener) a Dec2004
# Australia produce 666 unità per Australia (SmellSational Odor Eliminator) a Jan2004
# Australia produce 628 unità per Australia (SmellSational Odor Eliminator) a Feb2004
# Australia produce 627 unità per Australia (SmellSational Odor Eliminator) a Mar2004
# Australia produce 596 unità per Australia (SmellSational Odor Eliminator) a Apr2004
# Australia produce 606 unità per Australia (SmellSational Odor Eliminator) a May2004
# Australia produce 672 unità per Australia (SmellSational Odor Eliminator) a Jun2004
# Australia produce 570 unità per Australia (SmellSational Odor Eliminator) a Jul2004
# Australia produce 620 unità per Australia (SmellSational Odor Eliminator) a Aug2004
# Australia produce 638 unità per Australia (SmellSational Odor Eliminator) a Sep2004
# Australia produce 669 unità per Australia (SmellSational Odor Eliminator) a Oct2004
# Australia produce 583 unità per Australia (SmellSational Odor Eliminator) a Nov2004
# Australia produce 559 unità per Australia (SmellSational Odor Eliminator) a Dec2004
# Australia produce 1314 unità per Australia (LittleLullaby Diaper Cream) a Jan2004
# Australia produce 1441 unità per Australia (LittleLullaby Diaper Cream) a Feb2004
# Australia produce 1427 unità per Australia (LittleLullaby Diaper Cream) a Mar2004
# Australia produce 1265 unità per Australia (LittleLullaby Diaper Cream) a Apr2004
# Australia produce 1415 unità per Australia (LittleLullaby Diaper Cream) a May2004
# Australia produce 1483 unità per Australia (LittleLullaby Diaper Cream) a Jun2004
# Australia produce 1252 unità per Australia (LittleLullaby Diaper Cream) a Jul2004
# Australia produce 1340 unità per Australia (LittleLullaby Diaper Cream) a Aug2004
# Australia produce 1383 unità per Australia (LittleLullaby Diaper Cream) a Sep2004
# Australia produce 1434 unità per Australia (LittleLullaby Diaper Cream) a Oct2004
# Australia produce 1321 unità per Australia (LittleLullaby Diaper Cream) a Nov2004
# Australia produce 1398 unità per Australia (LittleLullaby Diaper Cream) a Dec2004
# Australia produce 1096 unità per Australia (CalmingClean Bath Time Wash) a Jan2004
# Australia produce 968 unità per Australia (CalmingClean Bath Time Wash) a Feb2004
# Australia produce 1037 unità per Australia (CalmingClean Bath Time Wash) a Mar2004
# Australia produce 1138 unità per Australia (CalmingClean Bath Time Wash) a Apr2004
# Australia produce 1041 unità per Australia (CalmingClean Bath Time Wash) a May2004
# Australia produce 1020 unità per Australia (CalmingClean Bath Time Wash) a Jun2004
# Australia produce 1103 unità per Australia (CalmingClean Bath Time Wash) a Jul2004
# Australia produce 1002 unità per Australia (CalmingClean Bath Time Wash) a Aug2004
# Australia produce 1004 unità per Australia (CalmingClean Bath Time Wash) a Sep2004
# Australia produce 1099 unità per Australia (CalmingClean Bath Time Wash) a Oct2004
# Australia produce 1189 unità per Australia (CalmingClean Bath Time Wash) a Nov2004
# Australia produce 1046 unità per Australia (CalmingClean Bath Time Wash) a Dec2004
# Australia produce 524 unità per Australia (FreshFusion Diaper Rash Remedy) a Jan2004
# Australia produce 569 unità per Australia (FreshFusion Diaper Rash Remedy) a Feb2004
# Australia produce 610 unità per Australia (FreshFusion Diaper Rash Remedy) a Mar2004
# Australia produce 545 unità per Australia (FreshFusion Diaper Rash Remedy) a Apr2004
# Australia produce 564 unità per Australia (FreshFusion Diaper Rash Remedy) a May2004
# Australia produce 532 unità per Australia (FreshFusion Diaper Rash Remedy) a Jun2004
# Australia produce 500 unità per Australia (FreshFusion Diaper Rash Remedy) a Jul2004
# Australia produce 536 unità per Australia (FreshFusion Diaper Rash Remedy) a Aug2004
# Australia produce 558 unità per Australia (FreshFusion Diaper Rash Remedy) a Sep2004
# Australia produce 552 unità per Australia (FreshFusion Diaper Rash Remedy) a Oct2004
# Australia produce 531 unità per Australia (FreshFusion Diaper Rash Remedy) a Nov2004
# Australia produce 519 unità per Australia (FreshFusion Diaper Rash Remedy) a Dec2004
# Australia produce 1797 unità per Australia (SilkySkin Baby Cream) a Jan2004
# Australia produce 1692 unità per Australia (SilkySkin Baby Cream) a Feb2004
# Australia produce 1762 unità per Australia (SilkySkin Baby Cream) a Mar2004
# Australia produce 1824 unità per Australia (SilkySkin Baby Cream) a Apr2004
# Australia produce 1665 unità per Australia (SilkySkin Baby Cream) a May2004
# Australia produce 1795 unità per Australia (SilkySkin Baby Cream) a Jun2004
# Australia produce 1855 unità per Australia (SilkySkin Baby Cream) a Jul2004
# Australia produce 1663 unità per Australia (SilkySkin Baby Cream) a Aug2004
# Australia produce 2002 unità per Australia (SilkySkin Baby Cream) a Sep2004
# Australia produce 1612 unità per Australia (SilkySkin Baby Cream) a Oct2004
# Australia produce 1603 unità per Australia (SilkySkin Baby Cream) a Nov2004
# Australia produce 1944 unità per Australia (SilkySkin Baby Cream) a Dec2004
# Australia produce 1466 unità per Australia (SoftStep Baby Shampoo) a Jan2004
# Australia produce 1464 unità per Australia (SoftStep Baby Shampoo) a Feb2004
# Australia produce 1398 unità per Australia (SoftStep Baby Shampoo) a Mar2004
# Australia produce 1406 unità per Australia (SoftStep Baby Shampoo) a Apr2004
# Australia produce 1242 unità per Australia (SoftStep Baby Shampoo) a May2004
# Australia produce 631 unità per Australia (LittleLullaby Diaper Liners) a Sep2004
# Australia produce 679 unità per Australia (LittleLullaby Diaper Liners) a Oct2004
# Australia produce 652 unità per Australia (LittleLullaby Diaper Liners) a Nov2004
# Australia produce 560 unità per Australia (LittleLullaby Diaper Liners) a Dec2004
# Australia produce 1227 unità per Australia (SoothingSerenity Baby Rub) a Jan2004
# Australia produce 1272 unità per Australia (SoothingSerenity Baby Rub) a Feb2004
# Australia produce 1238 unità per Australia (SoothingSerenity Baby Rub) a Mar2004
# Australia produce 1210 unità per Australia (SoothingSerenity Baby Rub) a Apr2004
# Australia produce 1247 unità per Australia (SoothingSerenity Baby Rub) a May2004
# Australia produce 1287 unità per Australia (SoothingSerenity Baby Rub) a Jun2004
# Australia produce 1302 unità per Australia (SoothingSerenity Baby Rub) a Jul2004
# Australia produce 1271 unità per Australia (SoothingSerenity Baby Rub) a Aug2004
# Australia produce 1112 unità per Australia (SoothingSerenity Baby Rub) a Sep2004
# Australia produce 1172 unità per Australia (SoothingSerenity Baby Rub) a Oct2004
# Australia produce 1297 unità per Australia (SoothingSerenity Baby Rub) a Nov2004
# Australia produce 1173 unità per Australia (SoothingSerenity Baby Rub) a Dec2004
# Australia produce 548 unità per Australia (CalmingClean Diaper Rash Cream) a Jan2004
# Australia produce 585 unità per Australia (CalmingClean Diaper Rash Cream) a Feb2004
# Australia produce 548 unità per Australia (CalmingClean Diaper Rash Cream) a Mar2004
# Australia produce 541 unità per Australia (CalmingClean Diaper Rash Cream) a Apr2004
# Australia produce 499 unità per Australia (CalmingClean Diaper Rash Cream) a May2004
# Australia produce 520 unità per Australia (CalmingClean Diaper Rash Cream) a Jun2004
# Australia produce 482 unità per Australia (CalmingClean Diaper Rash Cream) a Jul2004
# Australia produce 457 unità per Australia (CalmingClean Diaper Rash Cream) a Aug2004
# Australia produce 482 unità per Australia (CalmingClean Diaper Rash Cream) a Sep2004
# Australia produce 511 unità per Australia (CalmingClean Diaper Rash Cream) a Oct2004
# Australia produce 477 unità per Australia (CalmingClean Diaper Rash Cream) a Nov2004
# Australia produce 483 unità per Australia (CalmingClean Diaper Rash Cream) a Dec2004
# Australia produce 579 unità per Australia (FreshFusion Baby Wipes) a Jan2004
# Australia produce 586 unità per Australia (FreshFusion Baby Wipes) a Feb2004
# Australia produce 672 unità per Australia (FreshFusion Baby Wipes) a Mar2004
# Australia produce 649 unità per Australia (FreshFusion Baby Wipes) a Apr2004
# Australia produce 601 unità per Australia (FreshFusion Baby Wipes) a May2004
# Australia produce 677 unità per Australia (FreshFusion Baby Wipes) a Jun2004
# Australia produce 673 unità per Australia (FreshFusion Baby Wipes) a Jul2004
# Australia produce 708 unità per Australia (FreshFusion Baby Wipes) a Aug2004
# Australia produce 681 unità per Australia (FreshFusion Baby Wipes) a Sep2004
# Australia produce 653 unità per Australia (FreshFusion Baby Wipes) a Oct2004
# Australia produce 666 unità per Australia (FreshFusion Baby Wipes) a Nov2004
# Australia produce 644 unità per Australia (FreshFusion Baby Wipes) a Dec2004
# Australia produce 681 unità per Australia (PurePore Baby Skincare Set) a Jan2004
# Australia produce 745 unità per Australia (PurePore Baby Skincare Set) a Feb2004
# Australia produce 686 unità per Australia (PurePore Baby Skincare Set) a Mar2004
# Australia produce 731 unità per Australia (PurePore Baby Skincare Set) a Apr2004
# Australia produce 703 unità per Australia (PurePore Baby Skincare Set) a May2004
# Australia produce 733 unità per Australia (PurePore Baby Skincare Set) a Jun2004
# Australia produce 687 unità per Australia (PurePore Baby Skincare Set) a Jul2004
# Australia produce 758 unità per Australia (PurePore Baby Skincare Set) a Aug2004
# Australia produce 663 unità per Australia (PurePore Baby Skincare Set) a Sep2004
# Australia produce 677 unità per Australia (PurePore Baby Skincare Set) a Oct2004
# Australia produce 670 unità per Australia (PurePore Baby Skincare Set) a Nov2004
# Australia produce 560 unità per Australia (PurePore Baby Skincare Set) a Dec2004
# Australia produce 1468 unità per Australia (SilkySkin Baby Moisturizer) a Jan2004
# Australia produce 1456 unità per Australia (SilkySkin Baby Moisturizer) a Feb2004
# Australia produce 1541 unità per Australia (SilkySkin Baby Moisturizer) a Mar2004
# Australia produce 1371 unità per Australia (SilkySkin Baby Moisturizer) a Apr2004
# Australia produce 1396 unità per Australia (SilkySkin Baby Moisturizer) a May2004
# Australia produce 1427 unità per Australia (SilkySkin Baby Moisturizer) a Jun2004
# Australia produce 1351 unità per Australia (SilkySkin Baby Moisturizer) a Jul2004
# Australia produce 1457 unità per Australia (SilkySkin Baby Moisturizer) a Aug2004
# Australia produce 1431 unità per Australia (SilkySkin Baby Moisturizer) a Sep2004
# Australia produce 1346 unità per Australia (SilkySkin Baby Moisturizer) a Oct2004
# Australia produce 1353 unità per Australia (SilkySkin Baby Moisturizer) a Nov2004
# Australia produce 1437 unità per Australia (SilkySkin Baby Moisturizer) a Dec2004
# Australia produce 1629 unità per Australia (GentleGlow Baby Face Wash) a Jan2004
# Australia produce 1383 unità per Australia (GentleGlow Baby Face Wash) a Feb2004
# Australia produce 1640 unità per Australia (GentleGlow Baby Face Wash) a Mar2004
# Australia produce 1573 unità per Australia (GentleGlow Baby Face Wash) a Apr2004
# Australia produce 1541 unità per Australia (GentleGlow Baby Face Wash) a May2004
# Australia produce 1536 unità per Australia (GentleGlow Baby Face Wash) a Jun2004
# Australia produce 1510 unità per Australia (GentleGlow Baby Face Wash) a Jul2004
# Australia produce 1368 unità per Australia (GentleGlow Baby Face Wash) a Aug2004
# Australia produce 1586 unità per Australia (GentleGlow Baby Face Wash) a Sep2004
# Australia produce 1433 unità per Australia (GentleGlow Baby Face Wash) a Oct2004
# Australia produce 1455 unità per Australia (GentleGlow Baby Face Wash) a Nov2004
# Australia produce 1573 unità per Australia (GentleGlow Baby Face Wash) a Dec2004
# Australia produce 1821 unità per Australia (SmellSational Baby Room Spray) a Jan2004
# Australia produce 1933 unità per Australia (SmellSational Baby Room Spray) a Feb2004
# Australia produce 1850 unità per Australia (SmellSational Baby Room Spray) a Mar2004
# Australia produce 1784 unità per Australia (SmellSational Baby Room Spray) a Apr2004
# Australia produce 1946 unità per Australia (SmellSational Baby Room Spray) a May2004
# Australia produce 1924 unità per Australia (SmellSational Baby Room Spray) a Jun2004
# Australia produce 2021 unità per Australia (SmellSational Baby Room Spray) a Jul2004
# Australia produce 1940 unità per Australia (SmellSational Baby Room Spray) a Aug2004
# Australia produce 1939 unità per Australia (SmellSational Baby Room Spray) a Sep2004
# Australia produce 1961 unità per Australia (SmellSational Baby Room Spray) a Oct2004
# Australia produce 2103 unità per Australia (SmellSational Baby Room Spray) a Nov2004
# Australia produce 1838 unità per Australia (SmellSational Baby Room Spray) a Dec2004
# Australia produce 821 unità per Australia (SilkSmooth Conditioner) a Jan2004
# Australia produce 741 unità per Australia (SilkSmooth Conditioner) a Feb2004
# Australia produce 704 unità per Australia (SilkSmooth Conditioner) a Mar2004
# Australia produce 760 unità per Australia (SilkSmooth Conditioner) a Apr2004
# Australia produce 636 unità per Australia (SilkSmooth Conditioner) a May2004
# Australia produce 777 unità per Australia (SilkSmooth Conditioner) a Jun2004
# Australia produce 705 unità per Australia (SilkSmooth Conditioner) a Jul2004
# Australia produce 657 unità per Australia (SilkSmooth Conditioner) a Aug2004
# Australia produce 780 unità per Australia (SilkSmooth Conditioner) a Sep2004
# Australia produce 695 unità per Australia (SilkSmooth Conditioner) a Oct2004
# Australia produce 691 unità per Australia (SilkSmooth Conditioner) a Nov2004
# Australia produce 778 unità per Australia (SilkSmooth Conditioner) a Dec2004
# Australia produce 1556 unità per Australia (FreshFusion Hair Mask) a Jan2004
# Australia produce 1565 unità per Australia (FreshFusion Hair Mask) a Feb2004
# Australia produce 1547 unità per Australia (FreshFusion Hair Mask) a Mar2004
# Australia produce 1646 unità per Australia (FreshFusion Hair Mask) a Apr2004
# Australia produce 1569 unità per Australia (FreshFusion Hair Mask) a May2004
# Australia produce 1614 unità per Australia (FreshFusion Hair Mask) a Jun2004
# Australia produce 1548 unità per Australia (FreshFusion Hair Mask) a Jul2004
# Australia produce 1483 unità per Australia (FreshFusion Hair Mask) a Aug2004
# Australia produce 1602 unità per Australia (FreshFusion Hair Mask) a Sep2004
# Australia produce 1559 unità per Australia (FreshFusion Hair Mask) a Oct2004
# Australia produce 1571 unità per Australia (FreshFusion Hair Mask) a Nov2004
# Australia produce 1638 unità per Australia (FreshFusion Hair Mask) a Dec2004
# Australia produce 643 unità per Australia (PurePore Sanitary Belt) a Jan2004
# Australia produce 664 unità per Australia (PurePore Sanitary Belt) a Feb2004
# Australia produce 630 unità per Australia (PurePore Sanitary Belt) a Mar2004
# Australia produce 644 unità per Australia (PurePore Sanitary Belt) a Apr2004
# Australia produce 670 unità per Australia (PurePore Sanitary Belt) a May2004
# Australia produce 711 unità per Australia (PurePore Sanitary Belt) a Jun2004
# Australia produce 664 unità per Australia (PurePore Sanitary Belt) a Jul2004
# Australia produce 633 unità per Australia (PurePore Sanitary Belt) a Aug2004
# Australia produce 641 unità per Australia (PurePore Sanitary Belt) a Sep2004
# Australia produce 656 unità per Australia (PurePore Sanitary Belt) a Oct2004
# Australia produce 681 unità per Australia (PurePore Sanitary Belt) a Nov2004
# Australia produce 660 unità per Australia (PurePore Sanitary Belt) a Dec2004
# Australia produce 1402 unità per Australia (SoothingSerenity Air Freshener) a Jan2004
# Australia produce 1332 unità per Australia (SoothingSerenity Air Freshener) a Feb2004
# Australia produce 1378 unità per Australia (SoothingSerenity Air Freshener) a Mar2004
# Australia produce 1411 unità per Australia (SoothingSerenity Air Freshener) a Apr2004
# Australia produce 1342 unità per Australia (SoothingSerenity Air Freshener) a May2004
# Australia produce 1489 unità per Australia (SoothingSerenity Air Freshener) a Jun2004
# Australia produce 1318 unità per Australia (SoothingSerenity Air Freshener) a Jul2004
# Australia produce 1403 unità per Australia (SoothingSerenity Air Freshener) a Aug2004
# Australia produce 1461 unità per Australia (SoothingSerenity Air Freshener) a Sep2004
# Australia produce 1498 unità per Australia (SoothingSerenity Air Freshener) a Oct2004
# Australia produce 1602 unità per Australia (SoothingSerenity Air Freshener) a Nov2004
# Australia produce 1473 unità per Australia (SoothingSerenity Air Freshener) a Dec2004
# Australia produce 793 unità per Australia (RadiantRose Glass Cleaner) a Jan2004
# Australia produce 783 unità per Australia (RadiantRose Glass Cleaner) a Feb2004
# Australia produce 767 unità per Australia (RadiantRose Glass Cleaner) a Mar2004
# Australia produce 723 unità per Australia (RadiantRose Glass Cleaner) a Apr2004
# Australia produce 745 unità per Australia (RadiantRose Glass Cleaner) a May2004
# Australia produce 786 unità per Australia (RadiantRose Glass Cleaner) a Jun2004
# Australia produce 674 unità per Australia (RadiantRose Glass Cleaner) a Jul2004
# Australia produce 755 unità per Australia (RadiantRose Glass Cleaner) a Aug2004
# Australia produce 809 unità per Australia (RadiantRose Glass Cleaner) a Sep2004
# Australia produce 688 unità per Australia (RadiantRose Glass Cleaner) a Oct2004
# Australia produce 741 unità per Australia (RadiantRose Glass Cleaner) a Nov2004
# Australia produce 750 unità per Australia (RadiantRose Glass Cleaner) a Dec2004
# Australia produce 1619 unità per Australia (CalmingClean Trash Bags) a Jan2004
# Australia produce 1679 unità per Australia (CalmingClean Trash Bags) a Feb2004
# Australia produce 1847 unità per Australia (CalmingClean Trash Bags) a Mar2004
# Australia produce 1658 unità per Australia (CalmingClean Trash Bags) a Apr2004
# Australia produce 1612 unità per Australia (CalmingClean Trash Bags) a May2004
# Australia produce 1617 unità per Australia (CalmingClean Trash Bags) a Jun2004
# Australia produce 1612 unità per Australia (CalmingClean Trash Bags) a Jul2004
# Australia produce 1734 unità per Australia (CalmingClean Trash Bags) a Aug2004
# Australia produce 1699 unità per Australia (CalmingClean Trash Bags) a Sep2004
# Australia produce 1648 unità per Australia (CalmingClean Trash Bags) a Oct2004
# Australia produce 1577 unità per Australia (CalmingClean Trash Bags) a Nov2004
# Australia produce 1642 unità per Australia (CalmingClean Trash Bags) a Dec2004
# Australia produce 1437 unità per Australia (RadiantRover Pet Conditioner) a Jan2004
# Australia produce 1462 unità per Australia (RadiantRover Pet Conditioner) a Feb2004
# Australia produce 1436 unità per Australia (RadiantRover Pet Conditioner) a Mar2004
# Australia produce 1512 unità per Australia (RadiantRover Pet Conditioner) a Apr2004
# Australia produce 1489 unità per Australia (RadiantRover Pet Conditioner) a May2004
# Australia produce 1476 unità per Australia (RadiantRover Pet Conditioner) a Jun2004
# Australia produce 1535 unità per Australia (RadiantRover Pet Conditioner) a Jul2004
# Australia produce 1526 unità per Australia (RadiantRover Pet Conditioner) a Aug2004
# Australia produce 1555 unità per Australia (RadiantRover Pet Conditioner) a Sep2004
# Australia produce 1635 unità per Australia (RadiantRover Pet Conditioner) a Oct2004
# Australia produce 1366 unità per Australia (RadiantRover Pet Conditioner) a Nov2004
# Australia produce 1541 unità per Australia (RadiantRover Pet Conditioner) a Dec2004
# Australia produce 630 unità per Australia (FreshFusion Flea and Tick Spray) a Jan2004
# Australia produce 597 unità per Australia (FreshFusion Flea and Tick Spray) a Feb2004
# Australia produce 648 unità per Australia (FreshFusion Flea and Tick Spray) a Mar2004
# Australia produce 682 unità per Australia (FreshFusion Flea and Tick Spray) a Apr2004
# Australia produce 593 unità per Australia (FreshFusion Flea and Tick Spray) a May2004
# Australia produce 654 unità per Australia (FreshFusion Flea and Tick Spray) a Jun2004
# Australia produce 711 unità per Australia (FreshFusion Flea and Tick Spray) a Jul2004
# Australia produce 700 unità per Australia (FreshFusion Flea and Tick Spray) a Aug2004
# Australia produce 586 unità per Australia (FreshFusion Flea and Tick Spray) a Sep2004
# Australia produce 664 unità per Australia (FreshFusion Flea and Tick Spray) a Oct2004
# Australia produce 607 unità per Australia (FreshFusion Flea and Tick Spray) a Nov2004
# Australia produce 666 unità per Australia (FreshFusion Flea and Tick Spray) a Dec2004
# Australia produce 569 unità per Australia (GentleGlow Pet Grooming Kit) a Jan2004
# Australia produce 547 unità per Australia (GentleGlow Pet Grooming Kit) a Feb2004
# Australia produce 597 unità per Australia (GentleGlow Pet Grooming Kit) a Mar2004
# Australia produce 557 unità per Australia (GentleGlow Pet Grooming Kit) a Apr2004
# Australia produce 526 unità per Australia (GentleGlow Pet Grooming Kit) a May2004
# Australia produce 627 unità per Australia (GentleGlow Pet Grooming Kit) a Jun2004
# Australia produce 586 unità per Australia (GentleGlow Pet Grooming Kit) a Jul2004
# Australia produce 567 unità per Australia (GentleGlow Pet Grooming Kit) a Aug2004
# Australia produce 577 unità per Australia (GentleGlow Pet Grooming Kit) a Sep2004
# Australia produce 562 unità per Australia (GentleGlow Pet Grooming Kit) a Oct2004
# Australia produce 576 unità per Australia (GentleGlow Pet Grooming Kit) a Nov2004
# Australia produce 557 unità per Australia (GentleGlow Pet Grooming Kit) a Dec2004
# Australia produce 863 unità per Australia (HydratingHoney Pet Wipes) a Jan2004
# Australia produce 852 unità per Australia (HydratingHoney Pet Wipes) a Feb2004
# Australia produce 828 unità per Australia (HydratingHoney Pet Wipes) a Mar2004
# Australia produce 943 unità per Australia (HydratingHoney Pet Wipes) a Apr2004
# Australia produce 873 unità per Australia (HydratingHoney Pet Wipes) a May2004
# Australia produce 924 unità per Australia (HydratingHoney Pet Wipes) a Jun2004
# Australia produce 840 unità per Australia (HydratingHoney Pet Wipes) a Jul2004
# Australia produce 925 unità per Australia (HydratingHoney Pet Wipes) a Aug2004
# Australia produce 782 unità per Australia (HydratingHoney Pet Wipes) a Sep2004
# Australia produce 820 unità per Australia (HydratingHoney Pet Wipes) a Oct2004
# Australia produce 811 unità per Australia (HydratingHoney Pet Wipes) a Nov2004
# Australia produce 871 unità per Australia (HydratingHoney Pet Wipes) a Dec2004
# Australia produce 1720 unità per Italy (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce 1701 unità per Italy (SoothingSerenity Hand Sanitizer) a Feb2004
# Australia produce 1948 unità per Italy (SoothingSerenity Hand Sanitizer) a Mar2004
# Australia produce 1694 unità per Italy (SoothingSerenity Hand Sanitizer) a Apr2004
# Australia produce 1828 unità per Italy (SoothingSerenity Hand Sanitizer) a May2004
# Australia produce 1654 unità per Italy (SoothingSerenity Hand Sanitizer) a Jun2004
# Australia produce 1831 unità per Italy (SoothingSerenity Hand Sanitizer) a Jul2004
# Australia produce 1808 unità per Italy (SoothingSerenity Hand Sanitizer) a Aug2004
# Australia produce 1819 unità per Italy (SoothingSerenity Hand Sanitizer) a Sep2004
# Australia produce 1722 unità per Italy (SoothingSerenity Hand Sanitizer) a Oct2004
# Australia produce 1855 unità per Italy (SoothingSerenity Hand Sanitizer) a Nov2004
# Australia produce 1932 unità per Italy (SoothingSerenity Hand Sanitizer) a Dec2004
# Australia produce 1470 unità per Italy (Hydrating Honey Body Lotion) a Jan2004
# Australia produce 1661 unità per Italy (Hydrating Honey Body Lotion) a Feb2004
# Australia produce 1589 unità per Italy (Hydrating Honey Body Lotion) a Mar2004
# Australia produce 1396 unità per Italy (Hydrating Honey Body Lotion) a Apr2004
# Australia produce 1553 unità per Italy (Hydrating Honey Body Lotion) a May2004
# Australia produce 1467 unità per Italy (Hydrating Honey Body Lotion) a Jun2004
# Australia produce 1485 unità per Italy (Hydrating Honey Body Lotion) a Jul2004
# Australia produce 1517 unità per Italy (Hydrating Honey Body Lotion) a Aug2004
# Australia produce 1616 unità per Italy (Hydrating Honey Body Lotion) a Sep2004
# Australia produce 1539 unità per Italy (Hydrating Honey Body Lotion) a Oct2004
# Australia produce 1511 unità per Italy (Hydrating Honey Body Lotion) a Nov2004
# Australia produce 1450 unità per Italy (Hydrating Honey Body Lotion) a Dec2004
# Australia produce 1475 unità per France (SoothingSerenity Hand Sanitizer) a Jan2004
# Australia produce 1538 unità per France (SoothingSerenity Hand Sanitizer) a Feb2004
# Australia produce 1516 unità per France (SoothingSerenity Hand Sanitizer) a Mar2004
# Australia produce 1516 unità per France (SoothingSerenity Hand Sanitizer) a Apr2004
# Australia produce 1688 unità per France (SoothingSerenity Hand Sanitizer) a May2004
# ...
# United Kingdom produce 843 unità per United Kingdom (SilkSmooth Conditioner) a Aug2004
# United Kingdom produce 828 unità per United Kingdom (SilkSmooth Conditioner) a Sep2004
# United Kingdom produce 899 unità per United Kingdom (SilkSmooth Conditioner) a Oct2004
# United Kingdom produce 871 unità per United Kingdom (SilkSmooth Conditioner) a Nov2004
# United Kingdom produce 898 unità per United Kingdom (SilkSmooth Conditioner) a Dec2004
# United Kingdom produce 2018 unità per United Kingdom (RadiantRose Hair Serum) a Jan2004
unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Jan2004
# United Kingdom produce 264 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Feb2004
# United Kingdom produce 206 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Mar2004
# United Kingdom produce 197 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a May2004
# United Kingdom produce 90 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Jun2004
# United Kingdom produce 1093 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Aug2004
# United Kingdom produce 620 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Oct2004
# United Kingdom produce 363 unità per United Kingdom (EasyWash Laundry Detergent for Delicates) a Nov2004
# United Kingdom produce 1953 unità per United Kingdom (RadiantRover Pet Conditioner) a Jan2004
# United Kingdom produce 1817 unità per United Kingdom (RadiantRover Pet Conditioner) a Feb2004
# United Kingdom produce 2047 unità per United Kingdom (RadiantRover Pet Conditioner) a Mar2004
# United Kingdom produce 1918 unità per United Kingdom (RadiantRover Pet Conditioner) a Apr2004
# United Kingdom produce 1821 unità per United Kingdom (RadiantRover Pet Conditioner) a May2004
# United Kingdom produce 1991 unità per United Kingdom (RadiantRover Pet Conditioner) a Jun2004
# United Kingdom produce 1923 unità per United Kingdom (RadiantRover Pet Conditioner) a Jul2004
# United Kingdom produce 1894 unità per United Kingdom (RadiantRover Pet Conditioner) a Aug2004
# United Kingdom produce 2199 unità per United Kingdom (RadiantRover Pet Conditioner) a Sep2004
# United Kingdom produce 1729 unità per United Kingdom (RadiantRover Pet Conditioner) a Oct2004
# United Kingdom produce 1943 unità per United Kingdom (RadiantRover Pet Conditioner) a Nov2004
# United Kingdom produce 2115 unità per United Kingdom (RadiantRover Pet Conditioner) a Dec2004
# United Kingdom produce 592 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Jan2004
# United Kingdom produce 587 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Feb2004
# United Kingdom produce 648 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Mar2004
# United Kingdom produce 607 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Apr2004
# United Kingdom produce 550 unità per United Kingdom (FreshFusion Flea and Tick Spray) a May2004
# United Kingdom produce 592 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Jun2004
# United Kingdom produce 589 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Jul2004
# United Kingdom produce 590 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Aug2004
# United Kingdom produce 588 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Sep2004
# United Kingdom produce 629 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Oct2004
# United Kingdom produce 605 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Nov2004
# United Kingdom produce 596 unità per United Kingdom (FreshFusion Flea and Tick Spray) a Dec2004
# United Kingdom produce 738 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Jan2004
# United Kingdom produce 717 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Feb2004
# United Kingdom produce 769 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Mar2004
# United Kingdom produce 667 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Apr2004
# United Kingdom produce 675 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a May2004
# United Kingdom produce 694 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Jun2004
# United Kingdom produce 751 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Jul2004
# United Kingdom produce 611 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Aug2004
# United Kingdom produce 747 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Sep2004
# United Kingdom produce 663 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Oct2004
# United Kingdom produce 639 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Nov2004
# United Kingdom produce 728 unità per United Kingdom (BrightBreeze Pet Odor Eliminator) a Dec2004
# United Kingdom produce 1039 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Jan2004
# United Kingdom produce 996 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Feb2004
# United Kingdom produce 892 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Mar2004
# United Kingdom produce 997 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Apr2004
# United Kingdom produce 1067 unità per United Kingdom (EasyWash Pet Laundry Detergent) a May2004
# United Kingdom produce 914 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Jun2004
# United Kingdom produce 937 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Jul2004
# United Kingdom produce 1108 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Aug2004
# United Kingdom produce 1024 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Sep2004
# United Kingdom produce 1051 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Oct2004
# United Kingdom produce 1015 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Nov2004
# United Kingdom produce 1094 unità per United Kingdom (EasyWash Pet Laundry Detergent) a Dec2004
# United Kingdom produce 1019 unità per United Kingdom (SmellSational Pet Deodorizer) a Jan2004
# United Kingdom produce 1043 unità per United Kingdom (SmellSational Pet Deodorizer) a Feb2004
# United Kingdom produce 1077 unità per United Kingdom (SmellSational Pet Deodorizer) a Mar2004
# United Kingdom produce 1135 unità per United Kingdom (SmellSational Pet Deodorizer) a Apr2004
# United Kingdom produce 1052 unità per United Kingdom (SmellSational Pet Deodorizer) a May2004
# United Kingdom produce 1105 unità per United Kingdom (SmellSational Pet Deodorizer) a Jun2004
# United Kingdom produce 1040 unità per United Kingdom (SmellSational Pet Deodorizer) a Jul2004
# United Kingdom produce 1078 unità per United Kingdom (SmellSational Pet Deodorizer) a Aug2004
# United Kingdom produce 1074 unità per United Kingdom (SmellSational Pet Deodorizer) a Sep2004
# United Kingdom produce 1031 unità per United Kingdom (SmellSational Pet Deodorizer) a Oct2004
# United Kingdom produce 1008 unità per United Kingdom (SmellSational Pet Deodorizer) a Nov2004
# United Kingdom produce 1154 unità per United Kingdom (SmellSational Pet Deodorizer) a Dec2004
# United Kingdom produce 1099 unità per United Kingdom (HydratingHoney Pet Wipes) a Jan2004
# United Kingdom produce 1212 unità per United Kingdom (HydratingHoney Pet Wipes) a Feb2004
# United Kingdom produce 1174 unità per United Kingdom (HydratingHoney Pet Wipes) a Mar2004
# United Kingdom produce 1125 unità per United Kingdom (HydratingHoney Pet Wipes) a Apr2004
# United Kingdom produce 1041 unità per United Kingdom (HydratingHoney Pet Wipes) a May2004
# United Kingdom produce 1147 unità per United Kingdom (HydratingHoney Pet Wipes) a Jun2004
# United Kingdom produce 1137 unità per United Kingdom (HydratingHoney Pet Wipes) a Jul2004
# United Kingdom produce 1169 unità per United Kingdom (HydratingHoney Pet Wipes) a Aug2004
# United Kingdom produce 1189 unità per United Kingdom (HydratingHoney Pet Wipes) a Sep2004
# United Kingdom produce 1128 unità per United Kingdom (HydratingHoney Pet Wipes) a Oct2004
# United Kingdom produce 1128 unità per United Kingdom (HydratingHoney Pet Wipes) a Nov2004
# United Kingdom produce 1215 unità per United Kingdom (HydratingHoney Pet Wipes) a Dec2004

# %%
# initialize two dataframes for the solution
# production_plan = pd.DataFrame(columns=['Country', 'Product', 'Month', 'Quantity'])
# shipment_plan = pd.DataFrame(columns=['Origin', 'Destination', 'Product', 'Month', 'Quantity'])

shipment_data = []

# fill the production_plan dataframe with the results
for (i, j, p, m), var in x.items():
	shipment_data.append({
        'Origin': i,
		'Destination': j,
		'Product': p,
		'Month': m,
		'Quantity': int(var.solution_value())
	})
    
shipment_plan = pd.DataFrame(shipment_data)

# %%
production_plan = shipment_plan.groupby(['Origin', 'Product', 'Month'], as_index=False).agg({'Quantity': 'sum'})
production_plan.rename(columns={'Origin': 'Country'}, inplace=True)
production_plan.to_csv('outputs/03_output_productionPlan_1239.csv', index=False)
shipment_plan.to_csv('outputs/03_output_shipments_1239.csv', index=False)
